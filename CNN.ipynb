# %%
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import SGD
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import load_model
from sklearn.metrics import classification_report

# %% [markdown]
# ## Read Data

# %%
img_size=224 #ResNet50 224x224
batch_size=64

datagen_train = ImageDataGenerator(
    rescale=1.0/255.0
)
train_generator = datagen_train.flow_from_directory(
    "C:/Users/fatem/Downloads/images_face/train",
    target_size=(img_size, img_size),
    color_mode="rgb",  # Use RGB for ResNet50
    batch_size=batch_size,
    class_mode="sparse",  # Use sparse for integer-encoded labels
    shuffle=True
)

datagen_test = ImageDataGenerator(
    rescale=1.0/255.0
)
test_generator = datagen_test.flow_from_directory(
    "C:/Users/fatem/Downloads/images_face/test",
    target_size=(img_size, img_size),
    color_mode="rgb", 
    batch_size=batch_size,
    class_mode="sparse",  
    shuffle=True
)
x_test, y_test = next(test_generator)
x_train, y_train = next(train_generator)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (64, 224, 224, 3)
# y_train shape: (64,)
# x_test shape: (64, 224, 224, 3)
# y_test shape: (64,)

# %% [markdown]
# # Transfer Learning

# %%
base_model=ResNet50(weights="imagenet",include_top=False,input_shape=(224,224,3))

# Add layers
x = base_model.output
x = Flatten()(x)
x = Dense(256,activation="relu")(x)
x = Dense(64,activation="relu")(x)
x = Dense(32,activation="relu")(x)
x = Dense(256,activation="relu")(x)
output = Dense(7,activation="softmax")(x)

# final model
model=Model(inputs=base_model.input,outputs=output)

# Freeze the base model
for layer in base_model.layers:
    layer.trainable=False

# Unfreez the base model 
for layer in base_model.layers[-10:]:
    layer.trainable=True

model.compile(optimizer=Adam(learning_rate=0.001),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ## Callbacks

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',  
    factor=0.5,               
    patience=5,               
    verbose=1,                 
    min_delta=0.02, 
)

checkpoint_callback_val = tf.keras.callbacks.ModelCheckpoint(
    'best_model_val_CNN.keras',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

checkpoint_callback_train = tf.keras.callbacks.ModelCheckpoint(
    'best_model_train_CNN.keras',
    monitor='accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=250,
    validation_data=test_generator,
    validation_steps=test_generator.samples // batch_size,
    callbacks=[checkpoint_callback_val,checkpoint_callback_train,reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.4391 - loss: 1.4510
# Epoch 1: val_accuracy improved from -inf to 0.38714, saving model to best_model_val_CNN.keras
#
# Epoch 1: accuracy improved from -inf to 0.43693, saving model to best_model_train_CNN.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 3311s 7s/step - accuracy: 0.4391 - loss: 1.4510 - val_accuracy: 0.3871 - val_loss: 1.7059 - learning_rate: 5.0000e-04
# Epoch 2/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 1:42:36 14s/step - accuracy: 0.3906 - loss: 1.5180
# Epoch 2: val_accuracy did not improve from 0.38714
#
# Epoch 2: accuracy did not improve from 0.43693
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.3906 - loss: 1.5180 - val_accuracy: 0.3000 - val_loss: 1.9433 - learning_rate: 5.0000e-04
# Epoch 3/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.4428 - loss: 1.4448
# Epoch 3: val_accuracy did not improve from 0.38714
#
# Epoch 3: accuracy improved from 0.43693 to 0.44140, saving model to best_model_train_CNN.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1977s 4s/step - accuracy: 0.4428 - loss: 1.4448 - val_accuracy: 0.3277 - val_loss: 2.3364 - learning_rate: 5.0000e-04
# Epoch 4/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 10:27 1s/step - accuracy: 0.4688 - loss: 1.3729
# Epoch 4: val_accuracy improved from 0.38714 to 0.50000, saving model to best_model_val_CNN.keras
#
# Epoch 4: accuracy improved from 0.44140 to 0.46875, saving model to best_model_train_CNN.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.4688 - loss: 1.3729 - val_accuracy: 0.5000 - val_loss: 2.1704 - learning_rate: 5.0000e-04
# Epoch 5/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4480 - loss: 1.4247
# Epoch 5: val_accuracy did not improve from 0.50000
#
# Epoch 5: accuracy did not improve from 0.46875
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 727s 2s/step - accuracy: 0.4480 - loss: 1.4247 - val_accuracy: 0.2826 - val_loss: 2.1193 - learning_rate: 5.0000e-04
# Epoch 6/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 9:50 1s/step - accuracy: 0.3750 - loss: 1.4820
# Epoch 6: val_accuracy did not improve from 0.50000
#
# Epoch 6: accuracy did not improve from 0.46875
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 2s 576us/step - accuracy: 0.3750 - loss: 1.4820 - val_accuracy: 0.0000e+00 - val_loss: 3.2500 - learning_rate: 5.0000e-04
# Epoch 7/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4510 - loss: 1.4227
# Epoch 7: val_accuracy did not improve from 0.50000
#
# Epoch 7: accuracy did not improve from 0.46875
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 724s 2s/step - accuracy: 0.4510 - loss: 1.4227 - val_accuracy: 0.2485 - val_loss: 5.3368 - learning_rate: 5.0000e-04
# Epoch 8/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 9:44 1s/step - accuracy: 0.4062 - loss: 1.5611
# Epoch 8: val_accuracy did not improve from 0.50000
#
# Epoch 8: accuracy did not improve from 0.46875
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 2s 556us/step - accuracy: 0.4062 - loss: 1.5611 - val_accuracy: 0.3000 - val_loss: 4.8875 - learning_rate: 5.0000e-04
# Epoch 9/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4581 - loss: 1.3945
# Epoch 9: val_accuracy did not improve from 0.50000
#
# Epoch 9: accuracy did not improve from 0.46875
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 726s 2s/step - accuracy: 0.4581 - loss: 1.3945 - val_accuracy: 0.4216 - val_loss: 1.5481 - learning_rate: 5.0000e-04
# Epoch 10/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 5:59 803ms/step - accuracy: 0.4054 - loss: 1.5246
# Epoch 10: val_accuracy improved from 0.50000 to 0.60000, saving model to best_model_val_CNN.keras
#
# Epoch 10: accuracy did not improve from 0.46875
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4054 - loss: 1.5246 - val_accuracy: 0.6000 - val_loss: 1.3279 - learning_rate: 2.5000e-04
# Epoch 11/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - accuracy: 0.4745 - loss: 1.3705
# Epoch 11: val_accuracy did not improve from 0.60000
#
# Epoch 11: accuracy improved from 0.46875 to 0.47478, saving model to best_model_train_CNN.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 7608s 17s/step - accuracy: 0.4745 - loss: 1.3705 - val_accuracy: 0.4001 - val_loss: 1.5136 - learning_rate: 2.5000e-04
# Epoch 12/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 9:01 1s/step - accuracy: 0.5312 - loss: 1.2924
# Epoch 12: val_accuracy did not improve from 0.60000
#
# Epoch 12: accuracy improved from 0.47478 to 0.53125, saving model to best_model_train_CNN.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.5312 - loss: 1.2924 - val_accuracy: 0.2000 - val_loss: 1.6641 - learning_rate: 2.5000e-04
# Epoch 13/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4840 - loss: 1.3481
# Epoch 13: val_accuracy did not improve from 0.60000
#
# Epoch 13: accuracy did not improve from 0.53125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 2006s 4s/step - accuracy: 0.4840 - loss: 1.3481 - val_accuracy: 0.3248 - val_loss: 1.9049 - learning_rate: 2.5000e-04
# Epoch 14/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 1:04:06 9s/step - accuracy: 0.3906 - loss: 1.4127
# Epoch 14: val_accuracy did not improve from 0.60000
#
# Epoch 14: accuracy did not improve from 0.53125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.3906 - loss: 1.4127 - val_accuracy: 0.5000 - val_loss: 1.6259 - learning_rate: 2.5000e-04
# Epoch 15/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.4963 - loss: 1.3184
# Epoch 15: val_accuracy did not improve from 0.60000
#
# Epoch 15: accuracy did not improve from 0.53125
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 3569s 8s/step - accuracy: 0.4963 - loss: 1.3185 - val_accuracy: 0.4015 - val_loss: 1.5795 - learning_rate: 2.5000e-04
# Epoch 16/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:48 1s/step - accuracy: 0.5938 - loss: 1.0949
# Epoch 16: val_accuracy did not improve from 0.60000
#
# Epoch 16: accuracy improved from 0.53125 to 0.59375, saving model to best_model_train_CNN.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5938 - loss: 1.0949 - val_accuracy: 0.6000 - val_loss: 1.5531 - learning_rate: 1.2500e-04
# Epoch 17/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 34s/step - accuracy: 0.5045 - loss: 1.2914
# Epoch 17: val_accuracy did not improve from 0.60000
#
# Epoch 17: accuracy did not improve from 0.59375
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 15592s 35s/step - accuracy: 0.5045 - loss: 1.2914 - val_accuracy: 0.4107 - val_loss: 1.5595 - learning_rate: 1.2500e-04
# Epoch 18/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:40 1s/step - accuracy: 0.4688 - loss: 1.3390
# Epoch 18: val_accuracy did not improve from 0.60000
#
# Epoch 18: accuracy did not improve from 0.59375
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 574us/step - accuracy: 0.4688 - loss: 1.3390 - val_accuracy: 0.2000 - val_loss: 2.0950 - learning_rate: 1.2500e-04
# Epoch 19/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.5112 - loss: 1.2670
# Epoch 19: val_accuracy did not improve from 0.60000
#
# Epoch 19: accuracy did not improve from 0.59375
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 4301s 10s/step - accuracy: 0.5112 - loss: 1.2670 - val_accuracy: 0.4116 - val_loss: 1.6125 - learning_rate: 1.2500e-04
# Epoch 20/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 1:03:04 8s/step - accuracy: 0.5156 - loss: 1.3319
# Epoch 20: val_accuracy did not improve from 0.60000
#
# Epoch 20: accuracy did not improve from 0.59375
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.5156 - loss: 1.3319 - val_accuracy: 0.6000 - val_loss: 1.0826 - learning_rate: 1.2500e-04
# Epoch 21/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.5253 - loss: 1.2442
# Epoch 21: val_accuracy did not improve from 0.60000
#
# Epoch 21: accuracy did not improve from 0.59375
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 2623s 6s/step - accuracy: 0.5253 - loss: 1.2442 - val_accuracy: 0.4421 - val_loss: 1.4495 - learning_rate: 6.2500e-05
# Epoch 22/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:42 1s/step - accuracy: 0.5156 - loss: 1.2974
# Epoch 22: val_accuracy did not improve from 0.60000
#
# Epoch 22: accuracy did not improve from 0.59375
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 438us/step - accuracy: 0.5156 - loss: 1.2974 - val_accuracy: 0.5000 - val_loss: 1.4901 - learning_rate: 6.2500e-05
# Epoch 23/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5374 - loss: 1.2080
# Epoch 23: val_accuracy did not improve from 0.60000
#
# Epoch 23: accuracy did not improve from 0.59375
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 649s 1s/step - accuracy: 0.5374 - loss: 1.2080 - val_accuracy: 0.3751 - val_loss: 1.7221 - learning_rate: 6.2500e-05
# Epoch 24/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:49 1s/step - accuracy: 0.5469 - loss: 1.2600
# Epoch 24: val_accuracy did not improve from 0.60000
#
# Epoch 24: accuracy did not improve from 0.59375
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 478us/step - accuracy: 0.5469 - loss: 1.2600 - val_accuracy: 0.3000 - val_loss: 1.6695 - learning_rate: 6.2500e-05
# Epoch 25/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5397 - loss: 1.2011
# Epoch 25: val_accuracy did not improve from 0.60000
#
# Epoch 25: accuracy did not improve from 0.59375
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 649s 1s/step - accuracy: 0.5397 - loss: 1.2011 - val_accuracy: 0.4847 - val_loss: 1.3989 - learning_rate: 6.2500e-05
# Epoch 26/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:44 1s/step - accuracy: 0.5156 - loss: 1.1563
# Epoch 26: val_accuracy did not improve from 0.60000
#
# Epoch 26: accuracy did not improve from 0.59375
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 459us/step - accuracy: 0.5156 - loss: 1.1563 - val_accuracy: 0.6000 - val_loss: 1.2271 - learning_rate: 3.1250e-05
# Epoch 27/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5542 - loss: 1.1630
# Epoch 27: val_accuracy did not improve from 0.60000
#
# Epoch 27: accuracy did not improve from 0.59375
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 643s 1s/step - accuracy: 0.5542 - loss: 1.1630 - val_accuracy: 0.4812 - val_loss: 1.3944 - learning_rate: 3.1250e-05
# Epoch 28/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:40 1s/step - accuracy: 0.5781 - loss: 1.0940
# Epoch 28: val_accuracy did not improve from 0.60000
#
# Epoch 28: accuracy did not improve from 0.59375
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 438us/step - accuracy: 0.5781 - loss: 1.0940 - val_accuracy: 0.6000 - val_loss: 1.1860 - learning_rate: 3.1250e-05
# Epoch 29/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5689 - loss: 1.1352
# Epoch 29: val_accuracy did not improve from 0.60000
#
# Epoch 29: accuracy did not improve from 0.59375
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 644s 1s/step - accuracy: 0.5689 - loss: 1.1352 - val_accuracy: 0.4773 - val_loss: 1.4153 - learning_rate: 3.1250e-05
# Epoch 30/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:39 1s/step - accuracy: 0.6250 - loss: 1.0946
# Epoch 30: val_accuracy did not improve from 0.60000
#
# Epoch 30: accuracy improved from 0.59375 to 0.62500, saving model to best_model_train_CNN.keras
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6250 - loss: 1.0946 - val_accuracy: 0.3000 - val_loss: 1.8934 - learning_rate: 3.1250e-05
# Epoch 31/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5762 - loss: 1.1147
# Epoch 31: val_accuracy did not improve from 0.60000
#
# Epoch 31: accuracy did not improve from 0.62500
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 642s 1s/step - accuracy: 0.5762 - loss: 1.1147 - val_accuracy: 0.4835 - val_loss: 1.4022 - learning_rate: 1.5625e-05
# Epoch 32/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:37 1s/step - accuracy: 0.6719 - loss: 1.0052
# Epoch 32: val_accuracy did not improve from 0.60000
#
# Epoch 32: accuracy improved from 0.62500 to 0.67188, saving model to best_model_train_CNN.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6719 - loss: 1.0052 - val_accuracy: 0.3000 - val_loss: 2.6442 - learning_rate: 1.5625e-05
# Epoch 33/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5814 - loss: 1.1071
# Epoch 33: val_accuracy did not improve from 0.60000
#
# Epoch 33: accuracy did not improve from 0.67188
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 647s 1s/step - accuracy: 0.5814 - loss: 1.1071 - val_accuracy: 0.4833 - val_loss: 1.4131 - learning_rate: 1.5625e-05
# Epoch 34/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:38 1s/step - accuracy: 0.6875 - loss: 0.9276
# Epoch 34: val_accuracy did not improve from 0.60000
#
# Epoch 34: accuracy improved from 0.67188 to 0.68750, saving model to best_model_train_CNN.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6875 - loss: 0.9276 - val_accuracy: 0.6000 - val_loss: 1.1912 - learning_rate: 1.5625e-05
# Epoch 35/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5898 - loss: 1.0887
# Epoch 35: val_accuracy did not improve from 0.60000
#
# Epoch 35: accuracy did not improve from 0.68750
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 643s 1s/step - accuracy: 0.5898 - loss: 1.0887 - val_accuracy: 0.4803 - val_loss: 1.4271 - learning_rate: 1.5625e-05
# Epoch 36/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:37 1s/step - accuracy: 0.5781 - loss: 1.1302
# Epoch 36: val_accuracy did not improve from 0.60000
#
# Epoch 36: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 461us/step - accuracy: 0.5781 - loss: 1.1302 - val_accuracy: 0.4000 - val_loss: 1.8563 - learning_rate: 7.8125e-06
# Epoch 37/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5968 - loss: 1.0762
# Epoch 37: val_accuracy did not improve from 0.60000
#
# Epoch 37: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 642s 1s/step - accuracy: 0.5968 - loss: 1.0762 - val_accuracy: 0.4845 - val_loss: 1.4194 - learning_rate: 7.8125e-06
# Epoch 38/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:39 1s/step - accuracy: 0.4844 - loss: 1.2497
# Epoch 38: val_accuracy did not improve from 0.60000
#
# Epoch 38: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 443us/step - accuracy: 0.4844 - loss: 1.2497 - val_accuracy: 0.6000 - val_loss: 1.2291 - learning_rate: 7.8125e-06
# Epoch 39/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6024 - loss: 1.0604
# Epoch 39: val_accuracy did not improve from 0.60000
#
# Epoch 39: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 642s 1s/step - accuracy: 0.6024 - loss: 1.0604 - val_accuracy: 0.4866 - val_loss: 1.4223 - learning_rate: 7.8125e-06
# Epoch 40/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:41 1s/step - accuracy: 0.6250 - loss: 0.9317
# Epoch 40: val_accuracy did not improve from 0.60000
#
# Epoch 40: accuracy did not improve from 0.68750
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 435us/step - accuracy: 0.6250 - loss: 0.9317 - val_accuracy: 0.5000 - val_loss: 1.6604 - learning_rate: 7.8125e-06
# Epoch 41/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5947 - loss: 1.0667
# Epoch 41: val_accuracy did not improve from 0.60000
#
# Epoch 41: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 642s 1s/step - accuracy: 0.5948 - loss: 1.0667 - val_accuracy: 0.4884 - val_loss: 1.4210 - learning_rate: 3.9063e-06
# Epoch 42/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:43 1s/step - accuracy: 0.6719 - loss: 0.9988
# Epoch 42: val_accuracy did not improve from 0.60000
#
# Epoch 42: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 430us/step - accuracy: 0.6719 - loss: 0.9988 - val_accuracy: 0.3000 - val_loss: 1.7978 - learning_rate: 3.9063e-06
# Epoch 43/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6079 - loss: 1.0521
# Epoch 43: val_accuracy did not improve from 0.60000
#
# Epoch 43: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 643s 1s/step - accuracy: 0.6079 - loss: 1.0521 - val_accuracy: 0.4851 - val_loss: 1.4271 - learning_rate: 3.9063e-06
# Epoch 44/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:42 1s/step - accuracy: 0.5469 - loss: 1.1096
# Epoch 44: val_accuracy did not improve from 0.60000
#
# Epoch 44: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 453us/step - accuracy: 0.5469 - loss: 1.1096 - val_accuracy: 0.6000 - val_loss: 1.0027 - learning_rate: 3.9063e-06
# Epoch 45/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6032 - loss: 1.0579
# Epoch 45: val_accuracy did not improve from 0.60000
#
# Epoch 45: accuracy did not improve from 0.68750
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 641s 1s/step - accuracy: 0.6032 - loss: 1.0579 - val_accuracy: 0.4890 - val_loss: 1.4270 - learning_rate: 3.9063e-06
# Epoch 46/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:39 1s/step - accuracy: 0.6406 - loss: 1.0327
# Epoch 46: val_accuracy did not improve from 0.60000
#
# Epoch 46: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 446us/step - accuracy: 0.6406 - loss: 1.0327 - val_accuracy: 0.5000 - val_loss: 1.4321 - learning_rate: 1.9531e-06
# Epoch 47/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6111 - loss: 1.0429
# Epoch 47: val_accuracy did not improve from 0.60000
#
# Epoch 47: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 643s 1s/step - accuracy: 0.6111 - loss: 1.0429 - val_accuracy: 0.4881 - val_loss: 1.4278 - learning_rate: 1.9531e-06
# Epoch 48/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:39 1s/step - accuracy: 0.5938 - loss: 1.0998
# Epoch 48: val_accuracy did not improve from 0.60000
#
# Epoch 48: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 436us/step - accuracy: 0.5938 - loss: 1.0998 - val_accuracy: 0.4000 - val_loss: 2.0099 - learning_rate: 1.9531e-06
# Epoch 49/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6158 - loss: 1.0407
# Epoch 49: val_accuracy did not improve from 0.60000
#
# Epoch 49: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 642s 1s/step - accuracy: 0.6158 - loss: 1.0407 - val_accuracy: 0.4863 - val_loss: 1.4266 - learning_rate: 1.9531e-06
# Epoch 50/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:39 1s/step - accuracy: 0.5625 - loss: 1.1313
# Epoch 50: val_accuracy did not improve from 0.60000
#
# Epoch 50: accuracy did not improve from 0.68750
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 429us/step - accuracy: 0.5625 - loss: 1.1313 - val_accuracy: 0.4000 - val_loss: 2.8822 - learning_rate: 1.9531e-06
# Epoch 51/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6112 - loss: 1.0457
# Epoch 51: val_accuracy did not improve from 0.60000
#
# Epoch 51: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 644s 1s/step - accuracy: 0.6112 - loss: 1.0457 - val_accuracy: 0.4863 - val_loss: 1.4298 - learning_rate: 9.7656e-07
# Epoch 52/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:45 1s/step - accuracy: 0.6719 - loss: 0.9760
# Epoch 52: val_accuracy did not improve from 0.60000
#
# Epoch 52: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 449us/step - accuracy: 0.6719 - loss: 0.9760 - val_accuracy: 0.5000 - val_loss: 1.5297 - learning_rate: 9.7656e-07
# Epoch 53/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6150 - loss: 1.0360
# Epoch 53: val_accuracy did not improve from 0.60000
#
# Epoch 53: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 646s 1s/step - accuracy: 0.6150 - loss: 1.0360 - val_accuracy: 0.4872 - val_loss: 1.4285 - learning_rate: 9.7656e-07
# Epoch 54/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:46 1s/step - accuracy: 0.5625 - loss: 1.2444
# Epoch 54: val_accuracy did not improve from 0.60000
#
# Epoch 54: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 468us/step - accuracy: 0.5625 - loss: 1.2444 - val_accuracy: 0.3000 - val_loss: 1.9946 - learning_rate: 9.7656e-07
# Epoch 55/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6090 - loss: 1.0425
# Epoch 55: val_accuracy did not improve from 0.60000
#
# Epoch 55: accuracy did not improve from 0.68750
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 650s 1s/step - accuracy: 0.6090 - loss: 1.0425 - val_accuracy: 0.4873 - val_loss: 1.4313 - learning_rate: 9.7656e-07
# Epoch 56/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:44 1s/step - accuracy: 0.6719 - loss: 0.9270
# Epoch 56: val_accuracy did not improve from 0.60000
#
# Epoch 56: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 442us/step - accuracy: 0.6719 - loss: 0.9270 - val_accuracy: 0.2000 - val_loss: 1.3942 - learning_rate: 4.8828e-07
# Epoch 57/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6164 - loss: 1.0360
# Epoch 57: val_accuracy did not improve from 0.60000
#
# Epoch 57: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 648s 1s/step - accuracy: 0.6164 - loss: 1.0360 - val_accuracy: 0.4876 - val_loss: 1.4322 - learning_rate: 4.8828e-07
# Epoch 58/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:56 1s/step - accuracy: 0.5938 - loss: 0.9091
# Epoch 58: val_accuracy improved from 0.60000 to 0.70000, saving model to best_model_val_CNN.keras
#
# Epoch 58: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.5938 - loss: 0.9091 - val_accuracy: 0.7000 - val_loss: 0.7573 - learning_rate: 4.8828e-07
# Epoch 59/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6119 - loss: 1.0375
# Epoch 59: val_accuracy did not improve from 0.70000
#
# Epoch 59: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 649s 1s/step - accuracy: 0.6119 - loss: 1.0375 - val_accuracy: 0.4879 - val_loss: 1.4310 - learning_rate: 4.8828e-07
# Epoch 60/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:53 1s/step - accuracy: 0.6406 - loss: 1.0748
# Epoch 60: val_accuracy did not improve from 0.70000
#
# Epoch 60: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 434us/step - accuracy: 0.6406 - loss: 1.0748 - val_accuracy: 0.4000 - val_loss: 1.2216 - learning_rate: 4.8828e-07
# Epoch 61/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6089 - loss: 1.0468
# Epoch 61: val_accuracy did not improve from 0.70000
#
# Epoch 61: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 648s 1s/step - accuracy: 0.6089 - loss: 1.0468 - val_accuracy: 0.4877 - val_loss: 1.4319 - learning_rate: 4.8828e-07
# Epoch 62/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 9:23 1s/step - accuracy: 0.6719 - loss: 1.0396
# Epoch 62: val_accuracy did not improve from 0.70000
#
# Epoch 62: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 461us/step - accuracy: 0.6719 - loss: 1.0396 - val_accuracy: 0.7000 - val_loss: 1.1385 - learning_rate: 4.8828e-07
# Epoch 63/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6074 - loss: 1.0493
# Epoch 63: val_accuracy did not improve from 0.70000
#
# Epoch 63: accuracy did not improve from 0.68750
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 649s 1s/step - accuracy: 0.6074 - loss: 1.0493 - val_accuracy: 0.4883 - val_loss: 1.4322 - learning_rate: 4.8828e-07
# Epoch 64/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:43 1s/step - accuracy: 0.6719 - loss: 0.9124
# Epoch 64: val_accuracy did not improve from 0.70000
#
# Epoch 64: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 440us/step - accuracy: 0.6719 - loss: 0.9124 - val_accuracy: 0.4000 - val_loss: 1.1684 - learning_rate: 2.4414e-07
# Epoch 65/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6086 - loss: 1.0436
# Epoch 65: val_accuracy did not improve from 0.70000
#
# Epoch 65: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 650s 1s/step - accuracy: 0.6086 - loss: 1.0436 - val_accuracy: 0.4874 - val_loss: 1.4322 - learning_rate: 2.4414e-07
# Epoch 66/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 9:00 1s/step - accuracy: 0.5938 - loss: 1.0992
# Epoch 66: val_accuracy did not improve from 0.70000
#
# Epoch 66: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 470us/step - accuracy: 0.5938 - loss: 1.0992 - val_accuracy: 0.6000 - val_loss: 1.4888 - learning_rate: 2.4414e-07
# Epoch 67/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6150 - loss: 1.0326
# Epoch 67: val_accuracy did not improve from 0.70000
#
# Epoch 67: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 648s 1s/step - accuracy: 0.6150 - loss: 1.0326 - val_accuracy: 0.4876 - val_loss: 1.4336 - learning_rate: 2.4414e-07
# Epoch 68/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:41 1s/step - accuracy: 0.6406 - loss: 1.0168
# Epoch 68: val_accuracy improved from 0.70000 to 0.80000, saving model to best_model_val_CNN.keras
#
# Epoch 68: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6406 - loss: 1.0168 - val_accuracy: 0.8000 - val_loss: 0.8389 - learning_rate: 2.4414e-07
# Epoch 69/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6133 - loss: 1.0373
# Epoch 69: val_accuracy did not improve from 0.80000
#
# Epoch 69: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 648s 1s/step - accuracy: 0.6133 - loss: 1.0373 - val_accuracy: 0.4881 - val_loss: 1.4312 - learning_rate: 2.4414e-07
# Epoch 70/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:43 1s/step - accuracy: 0.5781 - loss: 1.1403
# Epoch 70: val_accuracy did not improve from 0.80000
#
# Epoch 70: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 444us/step - accuracy: 0.5781 - loss: 1.1403 - val_accuracy: 0.3000 - val_loss: 2.0340 - learning_rate: 2.4414e-07
# Epoch 71/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6101 - loss: 1.0387
# Epoch 71: val_accuracy did not improve from 0.80000
#
# Epoch 71: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 650s 1s/step - accuracy: 0.6101 - loss: 1.0387 - val_accuracy: 0.4877 - val_loss: 1.4322 - learning_rate: 2.4414e-07
# Epoch 72/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:54 1s/step - accuracy: 0.6719 - loss: 1.0405
# Epoch 72: val_accuracy did not improve from 0.80000
#
# Epoch 72: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 436us/step - accuracy: 0.6719 - loss: 1.0405 - val_accuracy: 0.3000 - val_loss: 1.5377 - learning_rate: 2.4414e-07
# Epoch 73/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6149 - loss: 1.0362
# Epoch 73: val_accuracy did not improve from 0.80000
#
# Epoch 73: accuracy did not improve from 0.68750
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 648s 1s/step - accuracy: 0.6149 - loss: 1.0363 - val_accuracy: 0.4884 - val_loss: 1.4312 - learning_rate: 2.4414e-07
# Epoch 74/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:44 1s/step - accuracy: 0.6094 - loss: 1.0608
# Epoch 74: val_accuracy did not improve from 0.80000
#
# Epoch 74: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 450us/step - accuracy: 0.6094 - loss: 1.0608 - val_accuracy: 0.2000 - val_loss: 1.9947 - learning_rate: 1.2207e-07
# Epoch 75/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6108 - loss: 1.0414
# Epoch 75: val_accuracy did not improve from 0.80000
#
# Epoch 75: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 648s 1s/step - accuracy: 0.6108 - loss: 1.0414 - val_accuracy: 0.4876 - val_loss: 1.4327 - learning_rate: 1.2207e-07
# Epoch 76/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:42 1s/step - accuracy: 0.5938 - loss: 1.0429
# Epoch 76: val_accuracy did not improve from 0.80000
#
# Epoch 76: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 434us/step - accuracy: 0.5938 - loss: 1.0429 - val_accuracy: 0.6000 - val_loss: 1.0678 - learning_rate: 1.2207e-07
# Epoch 77/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6166 - loss: 1.0286
# Epoch 77: val_accuracy did not improve from 0.80000
#
# Epoch 77: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 651s 1s/step - accuracy: 0.6165 - loss: 1.0286 - val_accuracy: 0.4893 - val_loss: 1.4334 - learning_rate: 1.2207e-07
# Epoch 78/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:44 1s/step - accuracy: 0.6406 - loss: 0.9982
# Epoch 78: val_accuracy did not improve from 0.80000
#
# Epoch 78: accuracy did not improve from 0.68750
#
# Epoch 78: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 439us/step - accuracy: 0.6406 - loss: 0.9982 - val_accuracy: 0.2000 - val_loss: 1.5893 - learning_rate: 1.2207e-07
# Epoch 79/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6155 - loss: 1.0314
# Epoch 79: val_accuracy did not improve from 0.80000
#
# Epoch 79: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 651s 1s/step - accuracy: 0.6155 - loss: 1.0315 - val_accuracy: 0.4886 - val_loss: 1.4325 - learning_rate: 6.1035e-08
# Epoch 80/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:46 1s/step - accuracy: 0.5469 - loss: 1.1030
# Epoch 80: val_accuracy did not improve from 0.80000
#
# Epoch 80: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 456us/step - accuracy: 0.5469 - loss: 1.1030 - val_accuracy: 0.4000 - val_loss: 1.2830 - learning_rate: 6.1035e-08
# Epoch 81/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6151 - loss: 1.0334
# Epoch 81: val_accuracy did not improve from 0.80000
#
# Epoch 81: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 649s 1s/step - accuracy: 0.6151 - loss: 1.0334 - val_accuracy: 0.4876 - val_loss: 1.4329 - learning_rate: 6.1035e-08
# Epoch 82/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:40 1s/step - accuracy: 0.5781 - loss: 1.1545
# Epoch 82: val_accuracy did not improve from 0.80000
#
# Epoch 82: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 482us/step - accuracy: 0.5781 - loss: 1.1545 - val_accuracy: 0.4000 - val_loss: 1.4986 - learning_rate: 6.1035e-08
# Epoch 83/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6126 - loss: 1.0367
# Epoch 83: val_accuracy did not improve from 0.80000
#
# Epoch 83: accuracy did not improve from 0.68750
#
# Epoch 83: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 648s 1s/step - accuracy: 0.6126 - loss: 1.0367 - val_accuracy: 0.4880 - val_loss: 1.4335 - learning_rate: 6.1035e-08
# Epoch 84/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:42 1s/step - accuracy: 0.6406 - loss: 1.0934
# Epoch 84: val_accuracy did not improve from 0.80000
#
# Epoch 84: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 443us/step - accuracy: 0.6406 - loss: 1.0934 - val_accuracy: 0.4000 - val_loss: 1.4482 - learning_rate: 3.0518e-08
# Epoch 85/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6171 - loss: 1.0303
# Epoch 85: val_accuracy did not improve from 0.80000
#
# Epoch 85: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 649s 1s/step - accuracy: 0.6170 - loss: 1.0303 - val_accuracy: 0.4879 - val_loss: 1.4336 - learning_rate: 3.0518e-08
# Epoch 86/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:42 1s/step - accuracy: 0.4688 - loss: 1.2147
# Epoch 86: val_accuracy did not improve from 0.80000
#
# Epoch 86: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 436us/step - accuracy: 0.4688 - loss: 1.2147 - val_accuracy: 0.5000 - val_loss: 1.5784 - learning_rate: 3.0518e-08
# Epoch 87/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6165 - loss: 1.0283
# Epoch 87: val_accuracy did not improve from 0.80000
#
# Epoch 87: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 651s 1s/step - accuracy: 0.6165 - loss: 1.0283 - val_accuracy: 0.4880 - val_loss: 1.4332 - learning_rate: 3.0518e-08
# Epoch 88/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:48 1s/step - accuracy: 0.5938 - loss: 1.0033
# Epoch 88: val_accuracy did not improve from 0.80000
#
# Epoch 88: accuracy did not improve from 0.68750
#
# Epoch 88: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 450us/step - accuracy: 0.5938 - loss: 1.0033 - val_accuracy: 0.3000 - val_loss: 1.7744 - learning_rate: 3.0518e-08
# Epoch 89/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6119 - loss: 1.0394
# Epoch 89: val_accuracy did not improve from 0.80000
#
# Epoch 89: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 650s 1s/step - accuracy: 0.6119 - loss: 1.0394 - val_accuracy: 0.4888 - val_loss: 1.4339 - learning_rate: 1.5259e-08
# Epoch 90/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:44 1s/step - accuracy: 0.6094 - loss: 1.0720
# Epoch 90: val_accuracy did not improve from 0.80000
#
# Epoch 90: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 452us/step - accuracy: 0.6094 - loss: 1.0720 - val_accuracy: 0.5000 - val_loss: 1.5488 - learning_rate: 1.5259e-08
# Epoch 91/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6117 - loss: 1.0478
# Epoch 91: val_accuracy did not improve from 0.80000
#
# Epoch 91: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 649s 1s/step - accuracy: 0.6117 - loss: 1.0477 - val_accuracy: 0.4872 - val_loss: 1.4339 - learning_rate: 1.5259e-08
# Epoch 92/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:47 1s/step - accuracy: 0.5625 - loss: 1.1583
# Epoch 92: val_accuracy did not improve from 0.80000
#
# Epoch 92: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 442us/step - accuracy: 0.5625 - loss: 1.1583 - val_accuracy: 0.8000 - val_loss: 1.0352 - learning_rate: 1.5259e-08
# Epoch 93/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6115 - loss: 1.0387
# Epoch 93: val_accuracy did not improve from 0.80000
#
# Epoch 93: accuracy did not improve from 0.68750
#
# Epoch 93: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 649s 1s/step - accuracy: 0.6115 - loss: 1.0387 - val_accuracy: 0.4880 - val_loss: 1.4316 - learning_rate: 1.5259e-08
# Epoch 94/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:41 1s/step - accuracy: 0.5000 - loss: 1.1826
# Epoch 94: val_accuracy did not improve from 0.80000
#
# Epoch 94: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 439us/step - accuracy: 0.5000 - loss: 1.1826 - val_accuracy: 0.5000 - val_loss: 1.6011 - learning_rate: 7.6294e-09
# Epoch 95/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6167 - loss: 1.0307
# Epoch 95: val_accuracy did not improve from 0.80000
#
# Epoch 95: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 643s 1s/step - accuracy: 0.6167 - loss: 1.0308 - val_accuracy: 0.4879 - val_loss: 1.4317 - learning_rate: 7.6294e-09
# Epoch 96/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:37 1s/step - accuracy: 0.6562 - loss: 1.0739
# Epoch 96: val_accuracy did not improve from 0.80000
#
# Epoch 96: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 432us/step - accuracy: 0.6562 - loss: 1.0739 - val_accuracy: 0.2000 - val_loss: 1.9863 - learning_rate: 7.6294e-09
# Epoch 97/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6165 - loss: 1.0308
# Epoch 97: val_accuracy did not improve from 0.80000
#
# Epoch 97: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 641s 1s/step - accuracy: 0.6165 - loss: 1.0308 - val_accuracy: 0.4877 - val_loss: 1.4335 - learning_rate: 7.6294e-09
# Epoch 98/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:39 1s/step - accuracy: 0.5625 - loss: 0.9911
# Epoch 98: val_accuracy did not improve from 0.80000
#
# Epoch 98: accuracy did not improve from 0.68750
#
# Epoch 98: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 434us/step - accuracy: 0.5625 - loss: 0.9911 - val_accuracy: 0.4000 - val_loss: 1.1220 - learning_rate: 7.6294e-09
# Epoch 99/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6133 - loss: 1.0366
# Epoch 99: val_accuracy did not improve from 0.80000
#
# Epoch 99: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 643s 1s/step - accuracy: 0.6133 - loss: 1.0366 - val_accuracy: 0.4891 - val_loss: 1.4343 - learning_rate: 3.8147e-09
# Epoch 100/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:51 1s/step - accuracy: 0.5625 - loss: 1.0889
# Epoch 100: val_accuracy did not improve from 0.80000
#
# Epoch 100: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 459us/step - accuracy: 0.5625 - loss: 1.0889 - val_accuracy: 0.7000 - val_loss: 0.8165 - learning_rate: 3.8147e-09
# Epoch 101/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6112 - loss: 1.0387
# Epoch 101: val_accuracy did not improve from 0.80000
#
# Epoch 101: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 644s 1s/step - accuracy: 0.6112 - loss: 1.0387 - val_accuracy: 0.4894 - val_loss: 1.4333 - learning_rate: 3.8147e-09
# Epoch 102/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:38 1s/step - accuracy: 0.4844 - loss: 1.1602
# Epoch 102: val_accuracy did not improve from 0.80000
#
# Epoch 102: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 448us/step - accuracy: 0.4844 - loss: 1.1602 - val_accuracy: 0.4000 - val_loss: 1.4742 - learning_rate: 3.8147e-09
# Epoch 103/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6112 - loss: 1.0454
# Epoch 103: val_accuracy did not improve from 0.80000
#
# Epoch 103: accuracy did not improve from 0.68750
#
# Epoch 103: ReduceLROnPlateau reducing learning rate to 1.907348723406699e-09.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 642s 1s/step - accuracy: 0.6112 - loss: 1.0454 - val_accuracy: 0.4876 - val_loss: 1.4337 - learning_rate: 3.8147e-09
# Epoch 104/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:45 1s/step - accuracy: 0.5312 - loss: 1.2553
# Epoch 104: val_accuracy did not improve from 0.80000
#
# Epoch 104: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 445us/step - accuracy: 0.5312 - loss: 1.2553 - val_accuracy: 0.8000 - val_loss: 0.7263 - learning_rate: 1.9073e-09
# Epoch 105/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6112 - loss: 1.0423
# Epoch 105: val_accuracy did not improve from 0.80000
#
# Epoch 105: accuracy did not improve from 0.68750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 644s 1s/step - accuracy: 0.6112 - loss: 1.0423 - val_accuracy: 0.4879 - val_loss: 1.4328 - learning_rate: 1.9073e-09
# Epoch 106/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:39 1s/step - accuracy: 0.7031 - loss: 0.9431
# Epoch 106: val_accuracy did not improve from 0.80000
#
# Epoch 106: accuracy improved from 0.68750 to 0.70312, saving model to best_model_train_CNN.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7031 - loss: 0.9431 - val_accuracy: 0.4000 - val_loss: 1.6929 - learning_rate: 1.9073e-09
# Epoch 107/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6195 - loss: 1.0301
# Epoch 107: val_accuracy did not improve from 0.80000
#
# Epoch 107: accuracy did not improve from 0.70312
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 641s 1s/step - accuracy: 0.6195 - loss: 1.0301 - val_accuracy: 0.4883 - val_loss: 1.4347 - learning_rate: 1.9073e-09
# Epoch 108/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:37 1s/step - accuracy: 0.6875 - loss: 0.8598
# Epoch 108: val_accuracy did not improve from 0.80000
#
# Epoch 108: accuracy did not improve from 0.70312
#
# Epoch 108: ReduceLROnPlateau reducing learning rate to 9.536743617033494e-10.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 427us/step - accuracy: 0.6875 - loss: 0.8598 - val_accuracy: 0.8000 - val_loss: 0.7103 - learning_rate: 1.9073e-09
# Epoch 109/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6136 - loss: 1.0333
# Epoch 109: val_accuracy did not improve from 0.80000
#
# Epoch 109: accuracy did not improve from 0.70312
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 641s 1s/step - accuracy: 0.6136 - loss: 1.0333 - val_accuracy: 0.4884 - val_loss: 1.4317 - learning_rate: 9.5367e-10
# Epoch 110/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:42 1s/step - accuracy: 0.7031 - loss: 1.0399
# Epoch 110: val_accuracy did not improve from 0.80000
#
# Epoch 110: accuracy did not improve from 0.70312
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 433us/step - accuracy: 0.7031 - loss: 1.0399 - val_accuracy: 0.5000 - val_loss: 1.9348 - learning_rate: 9.5367e-10
# Epoch 111/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6117 - loss: 1.0403
# Epoch 111: val_accuracy did not improve from 0.80000
#
# Epoch 111: accuracy did not improve from 0.70312
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 641s 1s/step - accuracy: 0.6117 - loss: 1.0403 - val_accuracy: 0.4872 - val_loss: 1.4319 - learning_rate: 9.5367e-10
# Epoch 112/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:35 1s/step - accuracy: 0.6406 - loss: 1.0401
# Epoch 112: val_accuracy did not improve from 0.80000
#
# Epoch 112: accuracy did not improve from 0.70312
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 428us/step - accuracy: 0.6406 - loss: 1.0401 - val_accuracy: 0.5000 - val_loss: 1.6572 - learning_rate: 9.5367e-10
# Epoch 113/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6153 - loss: 1.0373
# Epoch 113: val_accuracy did not improve from 0.80000
#
# Epoch 113: accuracy did not improve from 0.70312
#
# Epoch 113: ReduceLROnPlateau reducing learning rate to 4.768371808516747e-10.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 644s 1s/step - accuracy: 0.6153 - loss: 1.0373 - val_accuracy: 0.4872 - val_loss: 1.4325 - learning_rate: 9.5367e-10
# Epoch 114/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:43 1s/step - accuracy: 0.6406 - loss: 1.0044
# Epoch 114: val_accuracy did not improve from 0.80000
#
# Epoch 114: accuracy did not improve from 0.70312
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 422us/step - accuracy: 0.6406 - loss: 1.0044 - val_accuracy: 0.3000 - val_loss: 1.6548 - learning_rate: 4.7684e-10
# Epoch 115/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6132 - loss: 1.0402
# Epoch 115: val_accuracy did not improve from 0.80000
#
# Epoch 115: accuracy did not improve from 0.70312
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 637s 1s/step - accuracy: 0.6132 - loss: 1.0402 - val_accuracy: 0.4873 - val_loss: 1.4323 - learning_rate: 4.7684e-10
# Epoch 116/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:34 1s/step - accuracy: 0.4688 - loss: 1.3108
# Epoch 116: val_accuracy did not improve from 0.80000
#
# Epoch 116: accuracy did not improve from 0.70312
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 443us/step - accuracy: 0.4688 - loss: 1.3108 - val_accuracy: 0.5000 - val_loss: 1.5743 - learning_rate: 4.7684e-10
# Epoch 117/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6169 - loss: 1.0373
# Epoch 117: val_accuracy did not improve from 0.80000
#
# Epoch 117: accuracy did not improve from 0.70312
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 633s 1s/step - accuracy: 0.6169 - loss: 1.0373 - val_accuracy: 0.4873 - val_loss: 1.4337 - learning_rate: 4.7684e-10
# Epoch 118/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:36 1s/step - accuracy: 0.6875 - loss: 0.8273
# Epoch 118: val_accuracy did not improve from 0.80000
#
# Epoch 118: accuracy did not improve from 0.70312
#
# Epoch 118: ReduceLROnPlateau reducing learning rate to 2.3841859042583735e-10.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 434us/step - accuracy: 0.6875 - loss: 0.8273 - val_accuracy: 0.8000 - val_loss: 0.7076 - learning_rate: 4.7684e-10
# Epoch 119/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6065 - loss: 1.0493
# Epoch 119: val_accuracy did not improve from 0.80000
#
# Epoch 119: accuracy did not improve from 0.70312
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 632s 1s/step - accuracy: 0.6065 - loss: 1.0493 - val_accuracy: 0.4900 - val_loss: 1.4313 - learning_rate: 2.3842e-10
# Epoch 120/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:39 1s/step - accuracy: 0.6562 - loss: 0.9766
# Epoch 120: val_accuracy did not improve from 0.80000
#
# Epoch 120: accuracy did not improve from 0.70312
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 427us/step - accuracy: 0.6562 - loss: 0.9766 - val_accuracy: 0.2000 - val_loss: 1.7607 - learning_rate: 2.3842e-10
# Epoch 121/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6187 - loss: 1.0383
# Epoch 121: val_accuracy did not improve from 0.80000
#
# Epoch 121: accuracy did not improve from 0.70312
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 632s 1s/step - accuracy: 0.6186 - loss: 1.0383 - val_accuracy: 0.4880 - val_loss: 1.4342 - learning_rate: 2.3842e-10
# Epoch 122/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:37 1s/step - accuracy: 0.6562 - loss: 1.0662
# Epoch 122: val_accuracy did not improve from 0.80000
#
# Epoch 122: accuracy did not improve from 0.70312
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 444us/step - accuracy: 0.6562 - loss: 1.0662 - val_accuracy: 0.8000 - val_loss: 0.9787 - learning_rate: 2.3842e-10
# Epoch 123/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6196 - loss: 1.0287
# Epoch 123: val_accuracy did not improve from 0.80000
#
# Epoch 123: accuracy did not improve from 0.70312
#
# Epoch 123: ReduceLROnPlateau reducing learning rate to 1.1920929521291868e-10.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 634s 1s/step - accuracy: 0.6196 - loss: 1.0288 - val_accuracy: 0.4866 - val_loss: 1.4344 - learning_rate: 2.3842e-10
# Epoch 124/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:36 1s/step - accuracy: 0.6719 - loss: 0.9799
# Epoch 124: val_accuracy did not improve from 0.80000
#
# Epoch 124: accuracy did not improve from 0.70312
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 425us/step - accuracy: 0.6719 - loss: 0.9799 - val_accuracy: 0.8000 - val_loss: 0.9409 - learning_rate: 1.1921e-10
# Epoch 125/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6169 - loss: 1.0293
# Epoch 125: val_accuracy did not improve from 0.80000
#
# Epoch 125: accuracy did not improve from 0.70312
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 636s 1s/step - accuracy: 0.6169 - loss: 1.0293 - val_accuracy: 0.4895 - val_loss: 1.4328 - learning_rate: 1.1921e-10
# Epoch 126/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:37 1s/step - accuracy: 0.7812 - loss: 0.7956
# Epoch 126: val_accuracy did not improve from 0.80000
#
# Epoch 126: accuracy improved from 0.70312 to 0.78125, saving model to best_model_train_CNN.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7812 - loss: 0.7956 - val_accuracy: 0.3000 - val_loss: 2.4870 - learning_rate: 1.1921e-10
# Epoch 127/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6158 - loss: 1.0308
# Epoch 127: val_accuracy did not improve from 0.80000
#
# Epoch 127: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 634s 1s/step - accuracy: 0.6158 - loss: 1.0308 - val_accuracy: 0.4870 - val_loss: 1.4334 - learning_rate: 1.1921e-10
# Epoch 128/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:39 1s/step - accuracy: 0.7031 - loss: 0.8804
# Epoch 128: val_accuracy did not improve from 0.80000
#
# Epoch 128: accuracy did not improve from 0.78125
#
# Epoch 128: ReduceLROnPlateau reducing learning rate to 5.960464760645934e-11.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 431us/step - accuracy: 0.7031 - loss: 0.8804 - val_accuracy: 0.6000 - val_loss: 0.8177 - learning_rate: 1.1921e-10
# Epoch 129/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6182 - loss: 1.0288
# Epoch 129: val_accuracy did not improve from 0.80000
#
# Epoch 129: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 635s 1s/step - accuracy: 0.6182 - loss: 1.0288 - val_accuracy: 0.4894 - val_loss: 1.4322 - learning_rate: 5.9605e-11
# Epoch 130/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:41 1s/step - accuracy: 0.5625 - loss: 1.0776
# Epoch 130: val_accuracy did not improve from 0.80000
#
# Epoch 130: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 444us/step - accuracy: 0.5625 - loss: 1.0776 - val_accuracy: 0.2000 - val_loss: 1.5879 - learning_rate: 5.9605e-11
# Epoch 131/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6158 - loss: 1.0321
# Epoch 131: val_accuracy did not improve from 0.80000
#
# Epoch 131: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 634s 1s/step - accuracy: 0.6158 - loss: 1.0321 - val_accuracy: 0.4890 - val_loss: 1.4332 - learning_rate: 5.9605e-11
# Epoch 132/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:34 1s/step - accuracy: 0.6094 - loss: 1.0135
# Epoch 132: val_accuracy did not improve from 0.80000
#
# Epoch 132: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 428us/step - accuracy: 0.6094 - loss: 1.0135 - val_accuracy: 0.5000 - val_loss: 1.1380 - learning_rate: 5.9605e-11
# Epoch 133/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6107 - loss: 1.0367
# Epoch 133: val_accuracy did not improve from 0.80000
#
# Epoch 133: accuracy did not improve from 0.78125
#
# Epoch 133: ReduceLROnPlateau reducing learning rate to 2.980232380322967e-11.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 634s 1s/step - accuracy: 0.6107 - loss: 1.0367 - val_accuracy: 0.4870 - val_loss: 1.4334 - learning_rate: 5.9605e-11
# Epoch 134/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:44 1s/step - accuracy: 0.6562 - loss: 1.1017
# Epoch 134: val_accuracy did not improve from 0.80000
#
# Epoch 134: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 433us/step - accuracy: 0.6562 - loss: 1.1017 - val_accuracy: 0.7000 - val_loss: 0.9970 - learning_rate: 2.9802e-11
# Epoch 135/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6201 - loss: 1.0269
# Epoch 135: val_accuracy did not improve from 0.80000
#
# Epoch 135: accuracy did not improve from 0.78125
# ...
# Epoch 206/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:39 1s/step - accuracy: 0.6562 - loss: 0.8884
# Epoch 206: val_accuracy did not improve from 0.90000
#
# Epoch 206: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 442us/step - accuracy: 0.6562 - loss: 0.8884 - val_accuracy: 0.3000 - val_loss: 1.6249 - learning_rate: 1.8190e-15
# Epoch 207/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6121 - loss: 1.0477
# Epoch 207: val_accuracy did not improve from 0.90000
#
# Epoch 207: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 634s 1s/step - accuracy: 0.6121 - loss: 1.0477 - val_accuracy: 0.4886 - val_loss: 1.4329 - learning_rate: 1.8190e-15
# Epoch 208/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:40 1s/step - accuracy: 0.5156 - loss: 1.2302
# Epoch 208: val_accuracy did not improve from 0.90000
#
# Epoch 208: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 429us/step - accuracy: 0.5156 - loss: 1.2302 - val_accuracy: 0.3000 - val_loss: 2.3439 - learning_rate: 1.8190e-15
# Epoch 209/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6144 - loss: 1.0374
# Epoch 209: val_accuracy did not improve from 0.90000
#
# Epoch 209: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 635s 1s/step - accuracy: 0.6144 - loss: 1.0374 - val_accuracy: 0.4873 - val_loss: 1.4348 - learning_rate: 1.8190e-15
# Epoch 210/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:36 1s/step - accuracy: 0.5938 - loss: 1.1294
# Epoch 210: val_accuracy did not improve from 0.90000
#
# Epoch 210: accuracy did not improve from 0.78125
#
# Epoch 210: ReduceLROnPlateau reducing learning rate to 9.094947449716085e-16.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 433us/step - accuracy: 0.5938 - loss: 1.1294 - val_accuracy: 0.6000 - val_loss: 1.2388 - learning_rate: 1.8190e-15
# Epoch 211/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6126 - loss: 1.0406
# Epoch 211: val_accuracy did not improve from 0.90000
#
# Epoch 211: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 635s 1s/step - accuracy: 0.6126 - loss: 1.0406 - val_accuracy: 0.4890 - val_loss: 1.4316 - learning_rate: 9.0949e-16
# Epoch 212/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:36 1s/step - accuracy: 0.6094 - loss: 1.0667
# Epoch 212: val_accuracy did not improve from 0.90000
#
# Epoch 212: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 435us/step - accuracy: 0.6094 - loss: 1.0667 - val_accuracy: 0.3000 - val_loss: 2.1595 - learning_rate: 9.0949e-16
# Epoch 213/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6096 - loss: 1.0432
# Epoch 213: val_accuracy did not improve from 0.90000
#
# Epoch 213: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 635s 1s/step - accuracy: 0.6096 - loss: 1.0432 - val_accuracy: 0.4881 - val_loss: 1.4350 - learning_rate: 9.0949e-16
# Epoch 214/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:51 1s/step - accuracy: 0.6562 - loss: 0.8885
# Epoch 214: val_accuracy did not improve from 0.90000
#
# Epoch 214: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 457us/step - accuracy: 0.6562 - loss: 0.8885 - val_accuracy: 0.5000 - val_loss: 1.3074 - learning_rate: 9.0949e-16
# Epoch 215/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6126 - loss: 1.0379
# Epoch 215: val_accuracy did not improve from 0.90000
#
# Epoch 215: accuracy did not improve from 0.78125
#
# Epoch 215: ReduceLROnPlateau reducing learning rate to 4.547473724858043e-16.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 634s 1s/step - accuracy: 0.6126 - loss: 1.0379 - val_accuracy: 0.4890 - val_loss: 1.4333 - learning_rate: 9.0949e-16
# Epoch 216/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:44 1s/step - accuracy: 0.6875 - loss: 0.8231
# Epoch 216: val_accuracy did not improve from 0.90000
#
# Epoch 216: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 432us/step - accuracy: 0.6875 - loss: 0.8231 - val_accuracy: 0.5000 - val_loss: 1.4903 - learning_rate: 4.5475e-16
# Epoch 217/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6154 - loss: 1.0326
# Epoch 217: val_accuracy did not improve from 0.90000
#
# Epoch 217: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 636s 1s/step - accuracy: 0.6154 - loss: 1.0326 - val_accuracy: 0.4873 - val_loss: 1.4341 - learning_rate: 4.5475e-16
# Epoch 218/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:41 1s/step - accuracy: 0.7031 - loss: 0.8796
# Epoch 218: val_accuracy did not improve from 0.90000
#
# Epoch 218: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 430us/step - accuracy: 0.7031 - loss: 0.8796 - val_accuracy: 0.7000 - val_loss: 1.0162 - learning_rate: 4.5475e-16
# Epoch 219/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6166 - loss: 1.0324
# Epoch 219: val_accuracy did not improve from 0.90000
#
# Epoch 219: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 634s 1s/step - accuracy: 0.6166 - loss: 1.0325 - val_accuracy: 0.4887 - val_loss: 1.4342 - learning_rate: 4.5475e-16
# Epoch 220/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:39 1s/step - accuracy: 0.5781 - loss: 1.0627
# Epoch 220: val_accuracy did not improve from 0.90000
#
# Epoch 220: accuracy did not improve from 0.78125
#
# Epoch 220: ReduceLROnPlateau reducing learning rate to 2.2737368624290214e-16.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 448us/step - accuracy: 0.5781 - loss: 1.0627 - val_accuracy: 0.5000 - val_loss: 1.3248 - learning_rate: 4.5475e-16
# Epoch 221/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6105 - loss: 1.0380
# Epoch 221: val_accuracy did not improve from 0.90000
#
# Epoch 221: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 634s 1s/step - accuracy: 0.6105 - loss: 1.0380 - val_accuracy: 0.4877 - val_loss: 1.4324 - learning_rate: 2.2737e-16
# Epoch 222/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:45 1s/step - accuracy: 0.6562 - loss: 1.0263
# Epoch 222: val_accuracy did not improve from 0.90000
#
# Epoch 222: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 434us/step - accuracy: 0.6562 - loss: 1.0263 - val_accuracy: 0.3000 - val_loss: 1.9554 - learning_rate: 2.2737e-16
# Epoch 223/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6180 - loss: 1.0304
# Epoch 223: val_accuracy did not improve from 0.90000
#
# Epoch 223: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 634s 1s/step - accuracy: 0.6180 - loss: 1.0304 - val_accuracy: 0.4872 - val_loss: 1.4339 - learning_rate: 2.2737e-16
# Epoch 224/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:39 1s/step - accuracy: 0.6094 - loss: 0.9914
# Epoch 224: val_accuracy did not improve from 0.90000
#
# Epoch 224: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 424us/step - accuracy: 0.6094 - loss: 0.9914 - val_accuracy: 0.5000 - val_loss: 1.1380 - learning_rate: 2.2737e-16
# Epoch 225/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6147 - loss: 1.0311
# Epoch 225: val_accuracy did not improve from 0.90000
#
# Epoch 225: accuracy did not improve from 0.78125
#
# Epoch 225: ReduceLROnPlateau reducing learning rate to 1.1368684312145107e-16.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 634s 1s/step - accuracy: 0.6147 - loss: 1.0311 - val_accuracy: 0.4873 - val_loss: 1.4328 - learning_rate: 2.2737e-16
# Epoch 226/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:41 1s/step - accuracy: 0.5781 - loss: 1.1844
# Epoch 226: val_accuracy did not improve from 0.90000
#
# Epoch 226: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 430us/step - accuracy: 0.5781 - loss: 1.1844 - val_accuracy: 0.7000 - val_loss: 1.1679 - learning_rate: 1.1369e-16
# Epoch 227/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6135 - loss: 1.0323
# Epoch 227: val_accuracy did not improve from 0.90000
#
# Epoch 227: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 636s 1s/step - accuracy: 0.6135 - loss: 1.0324 - val_accuracy: 0.4870 - val_loss: 1.4332 - learning_rate: 1.1369e-16
# Epoch 228/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:56 1s/step - accuracy: 0.5000 - loss: 1.1292
# Epoch 228: val_accuracy did not improve from 0.90000
#
# Epoch 228: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 429us/step - accuracy: 0.5000 - loss: 1.1292 - val_accuracy: 0.5000 - val_loss: 2.0530 - learning_rate: 1.1369e-16
# Epoch 229/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6198 - loss: 1.0253
# Epoch 229: val_accuracy did not improve from 0.90000
#
# Epoch 229: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 634s 1s/step - accuracy: 0.6198 - loss: 1.0253 - val_accuracy: 0.4891 - val_loss: 1.4336 - learning_rate: 1.1369e-16
# Epoch 230/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:45 1s/step - accuracy: 0.5938 - loss: 1.0857
# Epoch 230: val_accuracy did not improve from 0.90000
#
# Epoch 230: accuracy did not improve from 0.78125
#
# Epoch 230: ReduceLROnPlateau reducing learning rate to 5.684342156072553e-17.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 431us/step - accuracy: 0.5938 - loss: 1.0857 - val_accuracy: 0.5000 - val_loss: 1.3018 - learning_rate: 1.1369e-16
# Epoch 231/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6133 - loss: 1.0338
# Epoch 231: val_accuracy did not improve from 0.90000
#
# Epoch 231: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 634s 1s/step - accuracy: 0.6133 - loss: 1.0339 - val_accuracy: 0.4888 - val_loss: 1.4332 - learning_rate: 5.6843e-17
# Epoch 232/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:41 1s/step - accuracy: 0.6875 - loss: 1.0490
# Epoch 232: val_accuracy did not improve from 0.90000
#
# Epoch 232: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 439us/step - accuracy: 0.6875 - loss: 1.0490 - val_accuracy: 0.7000 - val_loss: 1.0950 - learning_rate: 5.6843e-17
# Epoch 233/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6167 - loss: 1.0293
# Epoch 233: val_accuracy did not improve from 0.90000
#
# Epoch 233: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 633s 1s/step - accuracy: 0.6167 - loss: 1.0293 - val_accuracy: 0.4887 - val_loss: 1.4312 - learning_rate: 5.6843e-17
# Epoch 234/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:37 1s/step - accuracy: 0.6406 - loss: 0.9970
# Epoch 234: val_accuracy did not improve from 0.90000
#
# Epoch 234: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 424us/step - accuracy: 0.6406 - loss: 0.9970 - val_accuracy: 0.3000 - val_loss: 2.4179 - learning_rate: 5.6843e-17
# Epoch 235/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6169 - loss: 1.0347
# Epoch 235: val_accuracy did not improve from 0.90000
#
# Epoch 235: accuracy did not improve from 0.78125
#
# Epoch 235: ReduceLROnPlateau reducing learning rate to 2.842171078036277e-17.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 635s 1s/step - accuracy: 0.6169 - loss: 1.0347 - val_accuracy: 0.4874 - val_loss: 1.4333 - learning_rate: 5.6843e-17
# Epoch 236/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:41 1s/step - accuracy: 0.5469 - loss: 0.9437
# Epoch 236: val_accuracy did not improve from 0.90000
#
# Epoch 236: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 424us/step - accuracy: 0.5469 - loss: 0.9437 - val_accuracy: 0.6000 - val_loss: 1.2510 - learning_rate: 2.8422e-17
# Epoch 237/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6065 - loss: 1.0377
# Epoch 237: val_accuracy did not improve from 0.90000
#
# Epoch 237: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 634s 1s/step - accuracy: 0.6066 - loss: 1.0377 - val_accuracy: 0.4880 - val_loss: 1.4327 - learning_rate: 2.8422e-17
# Epoch 238/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:43 1s/step - accuracy: 0.7188 - loss: 0.8849
# Epoch 238: val_accuracy did not improve from 0.90000
#
# Epoch 238: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 428us/step - accuracy: 0.7188 - loss: 0.8849 - val_accuracy: 0.4000 - val_loss: 1.6987 - learning_rate: 2.8422e-17
# Epoch 239/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6136 - loss: 1.0387
# Epoch 239: val_accuracy did not improve from 0.90000
#
# Epoch 239: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 635s 1s/step - accuracy: 0.6136 - loss: 1.0387 - val_accuracy: 0.4888 - val_loss: 1.4337 - learning_rate: 2.8422e-17
# Epoch 240/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:40 1s/step - accuracy: 0.6406 - loss: 0.9353
# Epoch 240: val_accuracy did not improve from 0.90000
#
# Epoch 240: accuracy did not improve from 0.78125
#
# Epoch 240: ReduceLROnPlateau reducing learning rate to 1.4210855390181384e-17.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 428us/step - accuracy: 0.6406 - loss: 0.9353 - val_accuracy: 0.3000 - val_loss: 1.7211 - learning_rate: 2.8422e-17
# Epoch 241/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6124 - loss: 1.0384
# Epoch 241: val_accuracy did not improve from 0.90000
#
# Epoch 241: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 634s 1s/step - accuracy: 0.6124 - loss: 1.0384 - val_accuracy: 0.4881 - val_loss: 1.4349 - learning_rate: 1.4211e-17
# Epoch 242/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:33 1s/step - accuracy: 0.5312 - loss: 1.1161
# Epoch 242: val_accuracy did not improve from 0.90000
#
# Epoch 242: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 422us/step - accuracy: 0.5312 - loss: 1.1161 - val_accuracy: 0.7000 - val_loss: 0.5383 - learning_rate: 1.4211e-17
# Epoch 243/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6140 - loss: 1.0377
# Epoch 243: val_accuracy did not improve from 0.90000
#
# Epoch 243: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 633s 1s/step - accuracy: 0.6140 - loss: 1.0377 - val_accuracy: 0.4883 - val_loss: 1.4336 - learning_rate: 1.4211e-17
# Epoch 244/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:37 1s/step - accuracy: 0.6562 - loss: 0.9527
# Epoch 244: val_accuracy did not improve from 0.90000
#
# Epoch 244: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 423us/step - accuracy: 0.6562 - loss: 0.9527 - val_accuracy: 0.5000 - val_loss: 1.3799 - learning_rate: 1.4211e-17
# Epoch 245/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6197 - loss: 1.0285
# Epoch 245: val_accuracy did not improve from 0.90000
#
# Epoch 245: accuracy did not improve from 0.78125
#
# Epoch 245: ReduceLROnPlateau reducing learning rate to 7.105427695090692e-18.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 635s 1s/step - accuracy: 0.6197 - loss: 1.0285 - val_accuracy: 0.4874 - val_loss: 1.4334 - learning_rate: 1.4211e-17
# Epoch 246/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:36 1s/step - accuracy: 0.5469 - loss: 1.1207
# Epoch 246: val_accuracy did not improve from 0.90000
#
# Epoch 246: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 440us/step - accuracy: 0.5469 - loss: 1.1207 - val_accuracy: 0.6000 - val_loss: 1.1332 - learning_rate: 7.1054e-18
# Epoch 247/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6121 - loss: 1.0391
# Epoch 247: val_accuracy did not improve from 0.90000
#
# Epoch 247: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 633s 1s/step - accuracy: 0.6121 - loss: 1.0391 - val_accuracy: 0.4888 - val_loss: 1.4330 - learning_rate: 7.1054e-18
# Epoch 248/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:34 1s/step - accuracy: 0.7500 - loss: 0.8034
# Epoch 248: val_accuracy did not improve from 0.90000
#
# Epoch 248: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 441us/step - accuracy: 0.7500 - loss: 0.8034 - val_accuracy: 0.3000 - val_loss: 1.7640 - learning_rate: 7.1054e-18
# Epoch 249/250
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6135 - loss: 1.0353
# Epoch 249: val_accuracy did not improve from 0.90000
#
# Epoch 249: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 632s 1s/step - accuracy: 0.6135 - loss: 1.0353 - val_accuracy: 0.4887 - val_loss: 1.4341 - learning_rate: 7.1054e-18
# Epoch 250/250
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:43 1s/step - accuracy: 0.5469 - loss: 1.1133
# Epoch 250: val_accuracy did not improve from 0.90000
#
# Epoch 250: accuracy did not improve from 0.78125
#
# Epoch 250: ReduceLROnPlateau reducing learning rate to 3.552713847545346e-18.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 430us/step - accuracy: 0.5469 - loss: 1.1133 - val_accuracy: 0.5000 - val_loss: 1.3794 - learning_rate: 7.1054e-18

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Using the best model

# %%
best_model = load_model('best_model_val_CNN.keras')

x = best_model.output  # Get the output of the last layer of the loaded model
x = Dense(64, activation="relu")(x)
x = Dense(32, activation="relu")(x)
x = Dense(64, activation="relu")(x)
output = Dense(7, activation="softmax")(x)  

model = Model(inputs=best_model.input, outputs=output)


for layer in best_model.layers:
    layer.trainable = False
for layer in best_model.layers[-10:]:
    layer.trainable = True

model.compile(optimizer=Adam(learning_rate=0.001),
              metrics=["accuracy"])

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=100,
    validation_data=test_generator,
    validation_steps=test_generator.samples // batch_size,
    callbacks=[checkpoint_callback_val,checkpoint_callback_train,reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3763 - loss: 1.6113
# Epoch 1: val_accuracy did not improve from 0.90000
#
# Epoch 1: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 615s 1s/step - accuracy: 0.3763 - loss: 1.6111 - val_accuracy: 0.3965 - val_loss: 1.5019 - learning_rate: 0.0010
# Epoch 2/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:15 1s/step - accuracy: 0.5000 - loss: 1.4598
# c:\Users\fatem\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:155: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# Epoch 2: val_accuracy did not improve from 0.90000
#
# Epoch 2: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 686us/step - accuracy: 0.5000 - loss: 1.4598 - val_accuracy: 0.3000 - val_loss: 1.9060 - learning_rate: 0.0010
# Epoch 3/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4464 - loss: 1.4089
# Epoch 3: val_accuracy did not improve from 0.90000
#
# Epoch 3: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 611s 1s/step - accuracy: 0.4464 - loss: 1.4088 - val_accuracy: 0.4580 - val_loss: 1.4437 - learning_rate: 0.0010
# Epoch 4/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:15 1s/step - accuracy: 0.5469 - loss: 1.5025
# Epoch 4: val_accuracy did not improve from 0.90000
#
# Epoch 4: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 434us/step - accuracy: 0.5469 - loss: 1.5025 - val_accuracy: 0.6000 - val_loss: 1.3534 - learning_rate: 0.0010
# Epoch 5/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5104 - loss: 1.3025
# Epoch 5: val_accuracy did not improve from 0.90000
#
# Epoch 5: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 608s 1s/step - accuracy: 0.5104 - loss: 1.3025 - val_accuracy: 0.4397 - val_loss: 1.4518 - learning_rate: 0.0010
# Epoch 6/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:06 1s/step - accuracy: 0.5312 - loss: 1.2140
# Epoch 6: val_accuracy did not improve from 0.90000
#
# Epoch 6: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 431us/step - accuracy: 0.5312 - loss: 1.2140 - val_accuracy: 0.4000 - val_loss: 1.2610 - learning_rate: 0.0010
# Epoch 7/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5300 - loss: 1.2601
# Epoch 7: val_accuracy did not improve from 0.90000
#
# Epoch 7: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 607s 1s/step - accuracy: 0.5300 - loss: 1.2601 - val_accuracy: 0.4713 - val_loss: 1.4105 - learning_rate: 0.0010
# Epoch 8/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:17 1s/step - accuracy: 0.4531 - loss: 1.3553
# Epoch 8: val_accuracy did not improve from 0.90000
#
# Epoch 8: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 445us/step - accuracy: 0.4531 - loss: 1.3553 - val_accuracy: 0.6000 - val_loss: 1.1016 - learning_rate: 0.0010
# Epoch 9/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5511 - loss: 1.2146
# Epoch 9: val_accuracy did not improve from 0.90000
#
# Epoch 9: accuracy did not improve from 0.78125
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 606s 1s/step - accuracy: 0.5510 - loss: 1.2146 - val_accuracy: 0.4717 - val_loss: 1.4303 - learning_rate: 0.0010
# Epoch 10/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:19 1s/step - accuracy: 0.5156 - loss: 1.3356
# Epoch 10: val_accuracy did not improve from 0.90000
#
# Epoch 10: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 428us/step - accuracy: 0.5156 - loss: 1.3356 - val_accuracy: 0.5000 - val_loss: 1.1976 - learning_rate: 5.0000e-04
# Epoch 11/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5746 - loss: 1.1350
# Epoch 11: val_accuracy did not improve from 0.90000
#
# Epoch 11: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 605s 1s/step - accuracy: 0.5746 - loss: 1.1350 - val_accuracy: 0.4831 - val_loss: 1.4236 - learning_rate: 5.0000e-04
# Epoch 12/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:17 1s/step - accuracy: 0.5781 - loss: 1.2629
# Epoch 12: val_accuracy did not improve from 0.90000
#
# Epoch 12: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 439us/step - accuracy: 0.5781 - loss: 1.2629 - val_accuracy: 0.8000 - val_loss: 1.0562 - learning_rate: 5.0000e-04
# Epoch 13/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6024 - loss: 1.0800
# Epoch 13: val_accuracy did not improve from 0.90000
#
# Epoch 13: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 605s 1s/step - accuracy: 0.6024 - loss: 1.0800 - val_accuracy: 0.4865 - val_loss: 1.4615 - learning_rate: 5.0000e-04
# Epoch 14/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:19 1s/step - accuracy: 0.6562 - loss: 0.9418
# Epoch 14: val_accuracy did not improve from 0.90000
#
# Epoch 14: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 434us/step - accuracy: 0.6562 - loss: 0.9418 - val_accuracy: 0.4000 - val_loss: 1.6974 - learning_rate: 5.0000e-04
# Epoch 15/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6228 - loss: 1.0274
# Epoch 15: val_accuracy did not improve from 0.90000
#
# Epoch 15: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 606s 1s/step - accuracy: 0.6227 - loss: 1.0275 - val_accuracy: 0.4690 - val_loss: 1.4771 - learning_rate: 5.0000e-04
# Epoch 16/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:16 1s/step - accuracy: 0.6250 - loss: 1.0615
# Epoch 16: val_accuracy did not improve from 0.90000
#
# Epoch 16: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 423us/step - accuracy: 0.6250 - loss: 1.0615 - val_accuracy: 0.5000 - val_loss: 1.4768 - learning_rate: 5.0000e-04
# Epoch 17/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6380 - loss: 0.9978
# Epoch 17: val_accuracy did not improve from 0.90000
#
# Epoch 17: accuracy did not improve from 0.78125
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 606s 1s/step - accuracy: 0.6380 - loss: 0.9978 - val_accuracy: 0.4845 - val_loss: 1.4888 - learning_rate: 5.0000e-04
# Epoch 18/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:18 1s/step - accuracy: 0.7656 - loss: 0.8465
# Epoch 18: val_accuracy did not improve from 0.90000
#
# Epoch 18: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 427us/step - accuracy: 0.7656 - loss: 0.8465 - val_accuracy: 0.2000 - val_loss: 2.1227 - learning_rate: 2.5000e-04
# Epoch 19/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6779 - loss: 0.8936
# Epoch 19: val_accuracy did not improve from 0.90000
#
# Epoch 19: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 608s 1s/step - accuracy: 0.6779 - loss: 0.8936 - val_accuracy: 0.4724 - val_loss: 1.5599 - learning_rate: 2.5000e-04
# Epoch 20/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:19 1s/step - accuracy: 0.6719 - loss: 0.8840
# Epoch 20: val_accuracy did not improve from 0.90000
#
# Epoch 20: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 428us/step - accuracy: 0.6719 - loss: 0.8840 - val_accuracy: 0.6000 - val_loss: 1.9083 - learning_rate: 2.5000e-04
# Epoch 21/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6979 - loss: 0.8472
# Epoch 21: val_accuracy did not improve from 0.90000
#
# Epoch 21: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 606s 1s/step - accuracy: 0.6979 - loss: 0.8472 - val_accuracy: 0.4877 - val_loss: 1.6018 - learning_rate: 2.5000e-04
# Epoch 22/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:18 1s/step - accuracy: 0.6406 - loss: 1.0087
# Epoch 22: val_accuracy did not improve from 0.90000
#
# Epoch 22: accuracy did not improve from 0.78125
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 428us/step - accuracy: 0.6406 - loss: 1.0087 - val_accuracy: 0.4000 - val_loss: 1.7673 - learning_rate: 2.5000e-04
# Epoch 23/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7238 - loss: 0.7852
# Epoch 23: val_accuracy did not improve from 0.90000
#
# Epoch 23: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 605s 1s/step - accuracy: 0.7238 - loss: 0.7852 - val_accuracy: 0.4764 - val_loss: 1.6968 - learning_rate: 1.2500e-04
# Epoch 24/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:16 1s/step - accuracy: 0.7344 - loss: 0.7827
# Epoch 24: val_accuracy did not improve from 0.90000
#
# Epoch 24: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 425us/step - accuracy: 0.7344 - loss: 0.7827 - val_accuracy: 0.4000 - val_loss: 1.6821 - learning_rate: 1.2500e-04
# Epoch 25/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7379 - loss: 0.7357
# Epoch 25: val_accuracy did not improve from 0.90000
#
# Epoch 25: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 608s 1s/step - accuracy: 0.7379 - loss: 0.7357 - val_accuracy: 0.4901 - val_loss: 1.7031 - learning_rate: 1.2500e-04
# Epoch 26/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:14 1s/step - accuracy: 0.6875 - loss: 0.8200
# Epoch 26: val_accuracy did not improve from 0.90000
#
# Epoch 26: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 436us/step - accuracy: 0.6875 - loss: 0.8200 - val_accuracy: 0.5000 - val_loss: 1.8402 - learning_rate: 1.2500e-04
# Epoch 27/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7572 - loss: 0.7001
# Epoch 27: val_accuracy did not improve from 0.90000
#
# Epoch 27: accuracy did not improve from 0.78125
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 606s 1s/step - accuracy: 0.7572 - loss: 0.7001 - val_accuracy: 0.4866 - val_loss: 1.7390 - learning_rate: 1.2500e-04
# Epoch 28/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:18 1s/step - accuracy: 0.7656 - loss: 0.5674
# Epoch 28: val_accuracy did not improve from 0.90000
#
# Epoch 28: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 447us/step - accuracy: 0.7656 - loss: 0.5674 - val_accuracy: 0.5000 - val_loss: 1.8802 - learning_rate: 6.2500e-05
# Epoch 29/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7640 - loss: 0.6602
# Epoch 29: val_accuracy did not improve from 0.90000
#
# Epoch 29: accuracy did not improve from 0.78125
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 606s 1s/step - accuracy: 0.7640 - loss: 0.6602 - val_accuracy: 0.4855 - val_loss: 1.8205 - learning_rate: 6.2500e-05
# Epoch 30/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:17 1s/step - accuracy: 0.8281 - loss: 0.4964
# Epoch 30: val_accuracy did not improve from 0.90000
#
# Epoch 30: accuracy improved from 0.78125 to 0.82812, saving model to best_model_train_CNN.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8281 - loss: 0.4964 - val_accuracy: 0.4000 - val_loss: 2.9543 - learning_rate: 6.2500e-05
# Epoch 31/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7783 - loss: 0.6349
# Epoch 31: val_accuracy did not improve from 0.90000
#
# Epoch 31: accuracy did not improve from 0.82812
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 615s 1s/step - accuracy: 0.7783 - loss: 0.6349 - val_accuracy: 0.4856 - val_loss: 1.8687 - learning_rate: 6.2500e-05
# Epoch 32/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:17 1s/step - accuracy: 0.7344 - loss: 0.7817
# Epoch 32: val_accuracy did not improve from 0.90000
#
# Epoch 32: accuracy did not improve from 0.82812
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 432us/step - accuracy: 0.7344 - loss: 0.7817 - val_accuracy: 0.4000 - val_loss: 2.0558 - learning_rate: 6.2500e-05
# Epoch 33/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7890 - loss: 0.6055
# Epoch 33: val_accuracy did not improve from 0.90000
#
# Epoch 33: accuracy did not improve from 0.82812
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 607s 1s/step - accuracy: 0.7890 - loss: 0.6055 - val_accuracy: 0.4834 - val_loss: 1.8858 - learning_rate: 3.1250e-05
# Epoch 34/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:20 1s/step - accuracy: 0.7188 - loss: 0.6551
# Epoch 34: val_accuracy did not improve from 0.90000
#
# Epoch 34: accuracy did not improve from 0.82812
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 427us/step - accuracy: 0.7188 - loss: 0.6551 - val_accuracy: 0.4000 - val_loss: 2.5870 - learning_rate: 3.1250e-05
# Epoch 35/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7944 - loss: 0.5916
# Epoch 35: val_accuracy did not improve from 0.90000
#
# Epoch 35: accuracy did not improve from 0.82812
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 607s 1s/step - accuracy: 0.7944 - loss: 0.5916 - val_accuracy: 0.4835 - val_loss: 1.9360 - learning_rate: 3.1250e-05
# Epoch 36/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:17 1s/step - accuracy: 0.7969 - loss: 0.6475
# Epoch 36: val_accuracy did not improve from 0.90000
#
# Epoch 36: accuracy did not improve from 0.82812
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 425us/step - accuracy: 0.7969 - loss: 0.6475 - val_accuracy: 0.3000 - val_loss: 2.5622 - learning_rate: 3.1250e-05
# Epoch 37/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7966 - loss: 0.5889
# Epoch 37: val_accuracy did not improve from 0.90000
#
# Epoch 37: accuracy did not improve from 0.82812
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 607s 1s/step - accuracy: 0.7966 - loss: 0.5889 - val_accuracy: 0.4801 - val_loss: 1.9809 - learning_rate: 3.1250e-05
# Epoch 38/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:14 1s/step - accuracy: 0.7812 - loss: 0.7717
# Epoch 38: val_accuracy did not improve from 0.90000
#
# Epoch 38: accuracy did not improve from 0.82812
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 442us/step - accuracy: 0.7812 - loss: 0.7717 - val_accuracy: 0.7000 - val_loss: 1.1038 - learning_rate: 1.5625e-05
# Epoch 39/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8045 - loss: 0.5726
# Epoch 39: val_accuracy did not improve from 0.90000
#
# Epoch 39: accuracy did not improve from 0.82812
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 608s 1s/step - accuracy: 0.8045 - loss: 0.5726 - val_accuracy: 0.4810 - val_loss: 1.9838 - learning_rate: 1.5625e-05
# Epoch 40/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:17 1s/step - accuracy: 0.8906 - loss: 0.4117
# Epoch 40: val_accuracy did not improve from 0.90000
#
# Epoch 40: accuracy improved from 0.82812 to 0.89062, saving model to best_model_train_CNN.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8906 - loss: 0.4117 - val_accuracy: 0.7000 - val_loss: 1.0877 - learning_rate: 1.5625e-05
# Epoch 41/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8066 - loss: 0.5600
# Epoch 41: val_accuracy did not improve from 0.90000
#
# Epoch 41: accuracy did not improve from 0.89062
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 609s 1s/step - accuracy: 0.8066 - loss: 0.5600 - val_accuracy: 0.4819 - val_loss: 2.0013 - learning_rate: 1.5625e-05
# Epoch 42/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:15 1s/step - accuracy: 0.7656 - loss: 0.6245
# Epoch 42: val_accuracy did not improve from 0.90000
#
# Epoch 42: accuracy did not improve from 0.89062
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 438us/step - accuracy: 0.7656 - loss: 0.6245 - val_accuracy: 0.3000 - val_loss: 2.0350 - learning_rate: 1.5625e-05
# Epoch 43/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8043 - loss: 0.5660
# Epoch 43: val_accuracy did not improve from 0.90000
#
# Epoch 43: accuracy did not improve from 0.89062
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 607s 1s/step - accuracy: 0.8043 - loss: 0.5660 - val_accuracy: 0.4792 - val_loss: 2.0121 - learning_rate: 7.8125e-06
# Epoch 44/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:22 1s/step - accuracy: 0.8594 - loss: 0.4361
# Epoch 44: val_accuracy did not improve from 0.90000
#
# Epoch 44: accuracy did not improve from 0.89062
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 430us/step - accuracy: 0.8594 - loss: 0.4361 - val_accuracy: 0.3000 - val_loss: 2.7407 - learning_rate: 7.8125e-06
# Epoch 45/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8101 - loss: 0.5496
# Epoch 45: val_accuracy did not improve from 0.90000
#
# Epoch 45: accuracy did not improve from 0.89062
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 607s 1s/step - accuracy: 0.8101 - loss: 0.5496 - val_accuracy: 0.4812 - val_loss: 2.0189 - learning_rate: 7.8125e-06
# Epoch 46/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:18 1s/step - accuracy: 0.8281 - loss: 0.6109
# Epoch 46: val_accuracy did not improve from 0.90000
#
# Epoch 46: accuracy did not improve from 0.89062
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 436us/step - accuracy: 0.8281 - loss: 0.6109 - val_accuracy: 0.3000 - val_loss: 2.6012 - learning_rate: 7.8125e-06
# Epoch 47/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8115 - loss: 0.5493
# Epoch 47: val_accuracy did not improve from 0.90000
#
# Epoch 47: accuracy did not improve from 0.89062
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 607s 1s/step - accuracy: 0.8115 - loss: 0.5493 - val_accuracy: 0.4809 - val_loss: 2.0315 - learning_rate: 7.8125e-06
# Epoch 48/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:25 1s/step - accuracy: 0.8125 - loss: 0.4937
# Epoch 48: val_accuracy did not improve from 0.90000
#
# Epoch 48: accuracy did not improve from 0.89062
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 424us/step - accuracy: 0.8125 - loss: 0.4937 - val_accuracy: 0.5000 - val_loss: 2.0153 - learning_rate: 3.9063e-06
# Epoch 49/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8125 - loss: 0.5467
# Epoch 49: val_accuracy did not improve from 0.90000
#
# Epoch 49: accuracy did not improve from 0.89062
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 607s 1s/step - accuracy: 0.8125 - loss: 0.5467 - val_accuracy: 0.4785 - val_loss: 2.0301 - learning_rate: 3.9063e-06
# Epoch 50/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:17 1s/step - accuracy: 0.8438 - loss: 0.5843
# Epoch 50: val_accuracy did not improve from 0.90000
#
# Epoch 50: accuracy did not improve from 0.89062
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 425us/step - accuracy: 0.8438 - loss: 0.5843 - val_accuracy: 0.4000 - val_loss: 2.4253 - learning_rate: 3.9063e-06
# Epoch 51/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8160 - loss: 0.5427
# Epoch 51: val_accuracy did not improve from 0.90000
#
# Epoch 51: accuracy did not improve from 0.89062
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 607s 1s/step - accuracy: 0.8160 - loss: 0.5427 - val_accuracy: 0.4802 - val_loss: 2.0321 - learning_rate: 3.9063e-06
# Epoch 52/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:17 1s/step - accuracy: 0.8438 - loss: 0.4730
# Epoch 52: val_accuracy did not improve from 0.90000
#
# Epoch 52: accuracy did not improve from 0.89062
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 448us/step - accuracy: 0.8438 - loss: 0.4730 - val_accuracy: 0.6000 - val_loss: 0.8284 - learning_rate: 3.9063e-06
# Epoch 53/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8178 - loss: 0.5365
# Epoch 53: val_accuracy did not improve from 0.90000
#
# Epoch 53: accuracy did not improve from 0.89062
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 608s 1s/step - accuracy: 0.8178 - loss: 0.5365 - val_accuracy: 0.4813 - val_loss: 2.0329 - learning_rate: 1.9531e-06
# Epoch 54/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:18 1s/step - accuracy: 0.8750 - loss: 0.3236
# Epoch 54: val_accuracy did not improve from 0.90000
#
# Epoch 54: accuracy did not improve from 0.89062
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 430us/step - accuracy: 0.8750 - loss: 0.3236 - val_accuracy: 0.5000 - val_loss: 2.5350 - learning_rate: 1.9531e-06
# Epoch 55/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8153 - loss: 0.5380
# Epoch 55: val_accuracy did not improve from 0.90000
#
# Epoch 55: accuracy did not improve from 0.89062
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 608s 1s/step - accuracy: 0.8153 - loss: 0.5380 - val_accuracy: 0.4805 - val_loss: 2.0429 - learning_rate: 1.9531e-06
# Epoch 56/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:22 1s/step - accuracy: 0.7500 - loss: 0.6797
# Epoch 56: val_accuracy did not improve from 0.90000
#
# Epoch 56: accuracy did not improve from 0.89062
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 438us/step - accuracy: 0.7500 - loss: 0.6797 - val_accuracy: 0.7000 - val_loss: 1.1238 - learning_rate: 1.9531e-06
# Epoch 57/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8138 - loss: 0.5425
# Epoch 57: val_accuracy did not improve from 0.90000
#
# Epoch 57: accuracy did not improve from 0.89062
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 607s 1s/step - accuracy: 0.8138 - loss: 0.5424 - val_accuracy: 0.4814 - val_loss: 2.0390 - learning_rate: 1.9531e-06
# Epoch 58/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:20 1s/step - accuracy: 0.7812 - loss: 0.6681
# Epoch 58: val_accuracy did not improve from 0.90000
#
# Epoch 58: accuracy did not improve from 0.89062
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 426us/step - accuracy: 0.7812 - loss: 0.6681 - val_accuracy: 0.7000 - val_loss: 1.4370 - learning_rate: 9.7656e-07
# Epoch 59/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8187 - loss: 0.5297
# Epoch 59: val_accuracy did not improve from 0.90000
#
# Epoch 59: accuracy did not improve from 0.89062
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 607s 1s/step - accuracy: 0.8187 - loss: 0.5298 - val_accuracy: 0.4805 - val_loss: 2.0475 - learning_rate: 9.7656e-07
# Epoch 60/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:20 1s/step - accuracy: 0.8281 - loss: 0.4837
# Epoch 60: val_accuracy did not improve from 0.90000
#
# Epoch 60: accuracy did not improve from 0.89062
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 431us/step - accuracy: 0.8281 - loss: 0.4837 - val_accuracy: 0.6000 - val_loss: 2.4407 - learning_rate: 9.7656e-07
# Epoch 61/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8171 - loss: 0.5408
# Epoch 61: val_accuracy did not improve from 0.90000
#
# Epoch 61: accuracy did not improve from 0.89062
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 612s 1s/step - accuracy: 0.8171 - loss: 0.5408 - val_accuracy: 0.4812 - val_loss: 2.0443 - learning_rate: 9.7656e-07
# Epoch 62/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:16 1s/step - accuracy: 0.7500 - loss: 0.6442
# Epoch 62: val_accuracy did not improve from 0.90000
#
# Epoch 62: accuracy did not improve from 0.89062
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 430us/step - accuracy: 0.7500 - loss: 0.6442 - val_accuracy: 0.4000 - val_loss: 2.6074 - learning_rate: 9.7656e-07
# Epoch 63/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8146 - loss: 0.5445
# Epoch 63: val_accuracy did not improve from 0.90000
#
# Epoch 63: accuracy did not improve from 0.89062
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 608s 1s/step - accuracy: 0.8146 - loss: 0.5445 - val_accuracy: 0.4809 - val_loss: 2.0450 - learning_rate: 4.8828e-07
# Epoch 64/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:20 1s/step - accuracy: 0.8438 - loss: 0.6386
# Epoch 64: val_accuracy did not improve from 0.90000
#
# Epoch 64: accuracy did not improve from 0.89062
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 452us/step - accuracy: 0.8438 - loss: 0.6386 - val_accuracy: 0.6000 - val_loss: 1.5088 - learning_rate: 4.8828e-07
# Epoch 65/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8179 - loss: 0.5408
# Epoch 65: val_accuracy did not improve from 0.90000
#
# Epoch 65: accuracy did not improve from 0.89062
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 607s 1s/step - accuracy: 0.8178 - loss: 0.5408 - val_accuracy: 0.4813 - val_loss: 2.0430 - learning_rate: 4.8828e-07
# Epoch 66/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:16 1s/step - accuracy: 0.8906 - loss: 0.3488
# Epoch 66: val_accuracy did not improve from 0.90000
#
# Epoch 66: accuracy did not improve from 0.89062
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 436us/step - accuracy: 0.8906 - loss: 0.3488 - val_accuracy: 0.5000 - val_loss: 2.0636 - learning_rate: 4.8828e-07
# Epoch 67/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8165 - loss: 0.5440
# Epoch 67: val_accuracy did not improve from 0.90000
#
# Epoch 67: accuracy did not improve from 0.89062
#
# Epoch 67: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 608s 1s/step - accuracy: 0.8165 - loss: 0.5440 - val_accuracy: 0.4809 - val_loss: 2.0436 - learning_rate: 4.8828e-07
# Epoch 68/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:17 1s/step - accuracy: 0.7812 - loss: 0.5203
# Epoch 68: val_accuracy did not improve from 0.90000
#
# Epoch 68: accuracy did not improve from 0.89062
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 427us/step - accuracy: 0.7812 - loss: 0.5203 - val_accuracy: 0.4000 - val_loss: 2.5816 - learning_rate: 2.4414e-07
# Epoch 69/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8180 - loss: 0.5336
# Epoch 69: val_accuracy did not improve from 0.90000
#
# Epoch 69: accuracy did not improve from 0.89062
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 607s 1s/step - accuracy: 0.8179 - loss: 0.5336 - val_accuracy: 0.4821 - val_loss: 2.0372 - learning_rate: 2.4414e-07
# Epoch 70/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:21 1s/step - accuracy: 0.9375 - loss: 0.2787
# Epoch 70: val_accuracy did not improve from 0.90000
#
# Epoch 70: accuracy improved from 0.89062 to 0.93750, saving model to best_model_train_CNN.keras
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9375 - loss: 0.2787 - val_accuracy: 0.4000 - val_loss: 3.2309 - learning_rate: 2.4414e-07
# Epoch 71/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8151 - loss: 0.5422
# Epoch 71: val_accuracy did not improve from 0.90000
#
# Epoch 71: accuracy did not improve from 0.93750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 611s 1s/step - accuracy: 0.8151 - loss: 0.5422 - val_accuracy: 0.4809 - val_loss: 2.0452 - learning_rate: 2.4414e-07
# Epoch 72/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:18 1s/step - accuracy: 0.8438 - loss: 0.4682
# Epoch 72: val_accuracy did not improve from 0.90000
#
# Epoch 72: accuracy did not improve from 0.93750
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 454us/step - accuracy: 0.8438 - loss: 0.4682 - val_accuracy: 0.5000 - val_loss: 2.0197 - learning_rate: 2.4414e-07
# Epoch 73/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8132 - loss: 0.5515
# Epoch 73: val_accuracy did not improve from 0.90000
#
# Epoch 73: accuracy did not improve from 0.93750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 607s 1s/step - accuracy: 0.8132 - loss: 0.5515 - val_accuracy: 0.4812 - val_loss: 2.0461 - learning_rate: 1.2207e-07
# Epoch 74/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:20 1s/step - accuracy: 0.8750 - loss: 0.3687
# Epoch 74: val_accuracy did not improve from 0.90000
#
# Epoch 74: accuracy did not improve from 0.93750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 427us/step - accuracy: 0.8750 - loss: 0.3687 - val_accuracy: 0.3000 - val_loss: 2.4892 - learning_rate: 1.2207e-07
# Epoch 75/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8148 - loss: 0.5483
# Epoch 75: val_accuracy did not improve from 0.90000
#
# Epoch 75: accuracy did not improve from 0.93750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 607s 1s/step - accuracy: 0.8148 - loss: 0.5482 - val_accuracy: 0.4810 - val_loss: 2.0437 - learning_rate: 1.2207e-07
# Epoch 76/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:25 1s/step - accuracy: 0.8750 - loss: 0.3914
# Epoch 76: val_accuracy did not improve from 0.90000
#
# Epoch 76: accuracy did not improve from 0.93750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 490us/step - accuracy: 0.8750 - loss: 0.3914 - val_accuracy: 0.4000 - val_loss: 1.5861 - learning_rate: 1.2207e-07
# Epoch 77/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8154 - loss: 0.5403
# Epoch 77: val_accuracy did not improve from 0.90000
#
# Epoch 77: accuracy did not improve from 0.93750
#
# Epoch 77: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 607s 1s/step - accuracy: 0.8154 - loss: 0.5403 - val_accuracy: 0.4799 - val_loss: 2.0467 - learning_rate: 1.2207e-07
# Epoch 78/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:14 1s/step - accuracy: 0.8438 - loss: 0.4598
# Epoch 78: val_accuracy did not improve from 0.90000
#
# Epoch 78: accuracy did not improve from 0.93750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 439us/step - accuracy: 0.8438 - loss: 0.4598 - val_accuracy: 0.4000 - val_loss: 2.4678 - learning_rate: 6.1035e-08
# Epoch 79/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8142 - loss: 0.5476
# Epoch 79: val_accuracy did not improve from 0.90000
#
# Epoch 79: accuracy did not improve from 0.93750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 606s 1s/step - accuracy: 0.8142 - loss: 0.5476 - val_accuracy: 0.4806 - val_loss: 2.0476 - learning_rate: 6.1035e-08
# Epoch 80/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:19 1s/step - accuracy: 0.9375 - loss: 0.2707
# Epoch 80: val_accuracy did not improve from 0.90000
#
# Epoch 80: accuracy did not improve from 0.93750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 430us/step - accuracy: 0.9375 - loss: 0.2707 - val_accuracy: 0.8000 - val_loss: 0.8382 - learning_rate: 6.1035e-08
# Epoch 81/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8160 - loss: 0.5419
# Epoch 81: val_accuracy did not improve from 0.90000
#
# Epoch 81: accuracy did not improve from 0.93750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 607s 1s/step - accuracy: 0.8160 - loss: 0.5419 - val_accuracy: 0.4805 - val_loss: 2.0501 - learning_rate: 6.1035e-08
# Epoch 82/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:17 1s/step - accuracy: 0.8281 - loss: 0.4757
# Epoch 82: val_accuracy did not improve from 0.90000
#
# Epoch 82: accuracy did not improve from 0.93750
#
# Epoch 82: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 433us/step - accuracy: 0.8281 - loss: 0.4757 - val_accuracy: 0.7000 - val_loss: 1.4405 - learning_rate: 6.1035e-08
# Epoch 83/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8174 - loss: 0.5428
# Epoch 83: val_accuracy did not improve from 0.90000
#
# Epoch 83: accuracy did not improve from 0.93750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 607s 1s/step - accuracy: 0.8174 - loss: 0.5428 - val_accuracy: 0.4803 - val_loss: 2.0483 - learning_rate: 3.0518e-08
# Epoch 84/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:15 1s/step - accuracy: 0.8125 - loss: 0.4360
# Epoch 84: val_accuracy did not improve from 0.90000
#
# Epoch 84: accuracy did not improve from 0.93750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 443us/step - accuracy: 0.8125 - loss: 0.4360 - val_accuracy: 0.5000 - val_loss: 2.1921 - learning_rate: 3.0518e-08
# Epoch 85/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8184 - loss: 0.5331
# Epoch 85: val_accuracy did not improve from 0.90000
#
# Epoch 85: accuracy did not improve from 0.93750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 607s 1s/step - accuracy: 0.8184 - loss: 0.5331 - val_accuracy: 0.4810 - val_loss: 2.0440 - learning_rate: 3.0518e-08
# Epoch 86/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:18 1s/step - accuracy: 0.8594 - loss: 0.4510
# Epoch 86: val_accuracy did not improve from 0.90000
#
# Epoch 86: accuracy did not improve from 0.93750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 423us/step - accuracy: 0.8594 - loss: 0.4510 - val_accuracy: 0.5000 - val_loss: 2.3035 - learning_rate: 3.0518e-08
# Epoch 87/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8140 - loss: 0.5486
# Epoch 87: val_accuracy did not improve from 0.90000
#
# Epoch 87: accuracy did not improve from 0.93750
#
# Epoch 87: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 613s 1s/step - accuracy: 0.8140 - loss: 0.5486 - val_accuracy: 0.4809 - val_loss: 2.0475 - learning_rate: 3.0518e-08
# Epoch 88/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:19 1s/step - accuracy: 0.8438 - loss: 0.5677
# Epoch 88: val_accuracy did not improve from 0.90000
#
# Epoch 88: accuracy did not improve from 0.93750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 427us/step - accuracy: 0.8438 - loss: 0.5677 - val_accuracy: 0.6000 - val_loss: 1.9808 - learning_rate: 1.5259e-08
# Epoch 89/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8152 - loss: 0.5404
# Epoch 89: val_accuracy did not improve from 0.90000
#
# Epoch 89: accuracy did not improve from 0.93750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 607s 1s/step - accuracy: 0.8152 - loss: 0.5404 - val_accuracy: 0.4817 - val_loss: 2.0463 - learning_rate: 1.5259e-08
# Epoch 90/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:20 1s/step - accuracy: 0.8125 - loss: 0.5686
# Epoch 90: val_accuracy did not improve from 0.90000
#
# Epoch 90: accuracy did not improve from 0.93750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 423us/step - accuracy: 0.8125 - loss: 0.5686 - val_accuracy: 0.4000 - val_loss: 1.2302 - learning_rate: 1.5259e-08
# Epoch 91/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8152 - loss: 0.5395
# Epoch 91: val_accuracy did not improve from 0.90000
#
# Epoch 91: accuracy did not improve from 0.93750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 607s 1s/step - accuracy: 0.8152 - loss: 0.5395 - val_accuracy: 0.4803 - val_loss: 2.0465 - learning_rate: 1.5259e-08
# Epoch 92/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:18 1s/step - accuracy: 0.8750 - loss: 0.5045
# Epoch 92: val_accuracy did not improve from 0.90000
#
# Epoch 92: accuracy did not improve from 0.93750
#
# Epoch 92: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 441us/step - accuracy: 0.8750 - loss: 0.5045 - val_accuracy: 0.5000 - val_loss: 2.4285 - learning_rate: 1.5259e-08
# Epoch 93/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8168 - loss: 0.5359
# Epoch 93: val_accuracy did not improve from 0.90000
#
# Epoch 93: accuracy did not improve from 0.93750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 606s 1s/step - accuracy: 0.8168 - loss: 0.5359 - val_accuracy: 0.4812 - val_loss: 2.0462 - learning_rate: 7.6294e-09
# Epoch 94/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:15 1s/step - accuracy: 0.8125 - loss: 0.5631
# Epoch 94: val_accuracy did not improve from 0.90000
#
# Epoch 94: accuracy did not improve from 0.93750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 431us/step - accuracy: 0.8125 - loss: 0.5631 - val_accuracy: 0.5000 - val_loss: 2.1307 - learning_rate: 7.6294e-09
# Epoch 95/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8141 - loss: 0.5383
# Epoch 95: val_accuracy did not improve from 0.90000
#
# Epoch 95: accuracy did not improve from 0.93750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 606s 1s/step - accuracy: 0.8141 - loss: 0.5383 - val_accuracy: 0.4807 - val_loss: 2.0465 - learning_rate: 7.6294e-09
# Epoch 96/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:17 1s/step - accuracy: 0.7969 - loss: 0.4914
# Epoch 96: val_accuracy did not improve from 0.90000
#
# Epoch 96: accuracy did not improve from 0.93750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 424us/step - accuracy: 0.7969 - loss: 0.4914 - val_accuracy: 0.7000 - val_loss: 1.3097 - learning_rate: 7.6294e-09
# Epoch 97/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8150 - loss: 0.5421
# Epoch 97: val_accuracy did not improve from 0.90000
#
# Epoch 97: accuracy did not improve from 0.93750
#
# Epoch 97: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 606s 1s/step - accuracy: 0.8150 - loss: 0.5421 - val_accuracy: 0.4809 - val_loss: 2.0481 - learning_rate: 7.6294e-09
# Epoch 98/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:17 1s/step - accuracy: 0.8438 - loss: 0.4076
# Epoch 98: val_accuracy did not improve from 0.90000
#
# Epoch 98: accuracy did not improve from 0.93750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 439us/step - accuracy: 0.8438 - loss: 0.4076 - val_accuracy: 0.5000 - val_loss: 2.0749 - learning_rate: 3.8147e-09
# Epoch 99/100
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8145 - loss: 0.5415
# Epoch 99: val_accuracy did not improve from 0.90000
#
# Epoch 99: accuracy did not improve from 0.93750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 607s 1s/step - accuracy: 0.8145 - loss: 0.5415 - val_accuracy: 0.4806 - val_loss: 2.0465 - learning_rate: 3.8147e-09
# Epoch 100/100
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:24 1s/step - accuracy: 0.8438 - loss: 0.5037
# Epoch 100: val_accuracy did not improve from 0.90000
#
# Epoch 100: accuracy did not improve from 0.93750
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 427us/step - accuracy: 0.8438 - loss: 0.5037 - val_accuracy: 0.6000 - val_loss: 1.7314 - learning_rate: 3.8147e-09

# %%
# Define needed variables
tr_acc = history.history['accuracy']
tr_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
import seaborn as sns 
from sklearn.metrics import confusion_matrix

# Get the true labels and predicted labels for the validation set
validation_labels = test_generator.classes
validation_pred_probs = model.predict(test_generator)
validation_pred_labels = np.argmax(validation_pred_probs, axis=1)

# Compute the confusion matrix
confusion_mtx = confusion_matrix(validation_labels, validation_pred_labels)
class_names = list(train_generator.class_indices.keys())
sns.set()
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='YlGnBu', 
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 262s 2s/step

# %%
# Number of images to display
num_images =20
# Get a batch from the test generator
test_images, test_labels = next(test_generator)

# Make predictions on the batch
predictions = model.predict(test_images)
predicted_labels = np.argmax(predictions, axis=1).astype(int)

# Convert one-hot encoded test_labels to class indices if needed
if len(test_labels.shape) > 1 and test_labels.shape[1] > 1:
    true_labels = np.argmax(test_labels, axis=1).astype(int)  # Convert one-hot to class indices and ensure integer type
else:
    true_labels = test_labels.astype(int)  # Already integer class indices

# Emotion classes
Emotion_Classes = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

# Ensure that we don't try to access more images than we have
num_images = min(num_images, len(test_images))

# Plot the images with true and predicted labels
fig, axes = plt.subplots(nrows=4, ncols=5, figsize=(20, 10),
                         subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    if i < num_images:  # Ensure we do not exceed the number of available images
        img = test_images[i]
        true_label = Emotion_Classes[int(true_labels[i])]  # Convert index to integer
        pred_label = Emotion_Classes[int(predicted_labels[i])]  # Convert index to integer

        # Display the image
        ax.imshow(img)
        ax.set_title(f"True: {true_label}\nPred: {pred_label}", color='green' if true_label == pred_label else 'red')

plt.tight_layout()
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 583ms/step
